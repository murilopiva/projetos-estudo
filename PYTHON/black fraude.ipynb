# %%
import pandas as pd
with open("bf.csv") as arq:
    bf = pd.read_csv(arq)

bf
# Out:
#        User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0      1000001  P00069042      F   0-17          10             A
# 1      1000001  P00248942      F   0-17          10             A
# 2      1000001  P00087842      F   0-17          10             A
# 3      1000001  P00085442      F   0-17          10             A
# 4      1000002  P00285442      M    55+          16             C
# ...        ...        ...    ...    ...         ...           ...
# 88938  1001694  P00116742      M  26-35          12             B
# 88939  1001694  P00138542      M  26-35          12             B
# 88940  1001694  P00283342      M  26-35          12             B
# 88941  1001694  P00139942      M  26-35          12             B
# 88942  1001694  P00085642      M  26-35          12           NaN
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                              2             0.0                 3.0
# ...

# %%
s = pd.Series(bf['Gender'])
s.value_counts()
# Out:
# M    67176
# F    21767
# Name: Gender, dtype: int64

# %%
bf['Gender']
# Out:
# 0        F
# 1        F
# 2        F
# 3        F
# 4        M
#         ..
# 88938    M
# 88939    M
# 88940    M
# 88941    M
# 88942    M
# Name: Gender, Length: 88943, dtype: object

# %%
import seaborn as sns


ax = sns.swarmplot(x=bf['Purchase'], data=bf, color=".25")

# %%
import seaborn as sns


ax = sns.violinplot(x=bf['Gender'], y=bf['Purchase'], hue=bf['Marital_Status'],
                   data=bf, pallet='muted', split=True)
