# %%
import PyPDF2 as pdr

pdfobj = open("prova.pdf",'rb')
pdfReader = pdr.PdfFileReader(pdfobj)

#print(pdfReader.numPages)

pageobj = pdfReader.getPage(0)
x = pageobj.extractText()
print(x)
# Out:
# EngenhariaeAdministra˘c~aodeSistemasdeBancodeDados{
# Minera˘c~aodeDados
# Prova
# Nome:
# Instru˘c~oes:
# Somenteser~aoconsideradasrespostasnosespa˘cosmarcados.
# Casoab-
# solutamenteario,continuenoversoeindiqueclaramentequearespostaa
# noverso.
# Quest~ao
# Valor
# Nota
# 1
# 2,0
# 2
# 2,0
# 3
# 2,0
# 4
# 2,0
# 5
# 2,0
# Total
# 10,0
# 1.
# Umaconhecidacadeiadelojaseletr^onicaspretendeinstituirumsistemadepromo˘c~oesparaclientesapartirda
# alisedooricodecomprasporcategoriadeprodutos.Asseguintestransa˘c~oesser~aoconsideradasnaanalise:
# Tabela1:Transa˘c~oes
# celular
# TV
# eletr^onicos
# atica
# livro
# esporte-lazer
# casa-decora˘c~ao
# 1
# n~ao
# sim
# n~ao
# sim
# sim
# n~ao
# n~ao
# 2
# sim
# n~ao
# sim
# sim
# sim
# n~ao
# n~ao
# 3
# n~ao
# sim
# n~ao
# sim
# sim
# n~ao
# n~ao
# 4
# sim
# sim
# n~ao
# sim
# sim
# n~ao
# n~ao
# 5
# n~ao
# n~ao
# sim
# n~ao
# n~ao
# n~ao
# n~ao
# 6
# n~ao
# n~ao
# n~ao
# n~ao
# sim
# n~ao
# n~ao
# 7
# n~ao
# n~ao
# n~ao
# sim
# n~ao
# n~ao
# ...
