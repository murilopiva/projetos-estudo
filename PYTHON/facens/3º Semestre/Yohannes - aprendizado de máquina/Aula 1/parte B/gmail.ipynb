# %%
# Python 3.8.0
import smtplib
import time
import imaplib
import email
import traceback 
# -------------------------------------------------
#
# Utility to read email from Gmail Using Python
#
# ------------------------------------------------
FROM_EMAIL = "murilocpiva@gmail.com" 
FROM_PWD = "vulcano555" 
SMTP_SERVER = "smtp.gmail.com" 
SMTP_PORT = 465

def read_email_from_gmail():
    try:
        mail = imaplib.IMAP4_SSL(SMTP_SERVER)
        mail.login(FROM_EMAIL,FROM_PWD)
        mail.select('inbox')

        data = mail.search(None, 'ALL')
        mail_ids = data[1]
        id_list = mail_ids[0].split()   
        first_email_id = int(id_list[0])
        latest_email_id = int(id_list[-1])

        for i in range(latest_email_id,first_email_id, -1):
            data = mail.fetch(str(i), '(RFC822)' )
            for response_part in data:
                arr = response_part[0]
                if isinstance(arr, tuple):
                    msg = email.message_from_string(str(arr[1],'utf-8'))
                    email_subject = msg['subject']
                    email_from = msg['from']
                    print('From : ' + email_from + '\n')
                    print('Subject : ' + email_subject + '\n')

    except Exception as e:
        traceback.print_exc() 
        print(str(e))

read_email_from_gmail()
# Out:
# From : Google <no-reply@accounts.google.com>
#
# Subject : =?UTF-8?Q?Alerta_cr=C3=ADtico_de_seguran=C3=A7a?=
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : =?UTF-8?Q?Alerta_cr=C3=ADtico_de_seguran=C3=A7a?=
#
# From : LinkedIn <jobs-noreply@linkedin.com>
#
# Subject : =?UTF-8?Q?A_sua_candidatura_=C3=A0_vaga_de_Ci=C3=AAncia_de?=
#  =?UTF-8?Q?_dados_foi_visualizada_pela_Let's_Code.?=
#
# From : LinkedIn <jobs-noreply@linkedin.com>
#
# Subject : =?UTF-8?Q?A_sua_candidatura_=C3=A0_vaga_de_Engenheiro_de?=
#  =?UTF-8?Q?_dados_foi_visualizada_pela_Comsentimento.?=
#
# From : LinkedIn <jobs-noreply@linkedin.com>
#
# Subject : =?UTF-8?Q?Sua_candidatura_para__Engenheiro_de_Dados_=E2=80=93_Azure_Dat?=
#  =?UTF-8?Q?a_Factory_-_Ingl=C3=AAs_Avan=C3=A7ado_na_Tech_Mahindra_-_Brasil?=
#
# From : =?UTF-8?Q?Ci=C3=AAncia_dos_Dados?=
#  <suporte@cientistadedadosnapratica.com.br>
#
# Subject : Mini Treinamento de Machine Learning
#
# From : Eduardo Rocha <suporte@cientistadedadosnapratica.com.br>
#
# Subject : Mini Treinamento de Machine Learning
#
# From : LinkedIn <jobs-noreply@linkedin.com>
#
# Subject : Sua candidatura para Data Engineer na Luizalabs
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_Eng?=
#  =?UTF-8?Q?enheiro_de_P&D_-_PS_(Pesquisa_&_De?=
#  =?UTF-8?Q?senvolvimento_e_Servi=C3=A7os_de_Produt?=
#  =?UTF-8?Q?os_T=C3=A9cnicos)_na_Berry_Global,_Inc.?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_Unity_Developer_na_Realvi?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_D?=
#  =?UTF-8?Q?esenvolvedor_Python_na_WK_JobHub?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_?=
#  =?UTF-8?Q?Gerente_de_Data_Science_na_Neon?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_Cienti?=
#  =?UTF-8?Q?sta_de_Dados_Especialista__na_Syngenta?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_En?=
#  =?UTF-8?Q?genheiro_de_dados_na_Comsentimento?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_Ar?=
#  =?UTF-8?Q?quiteto_de_dados_na_Atento_Brasil?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_?=
#  =?UTF-8?Q?Analista_de_dados_na_B2W_Digital?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de?=
#  =?UTF-8?Q?_Ci=C3=AAncia_de_dados_na_Let's_Code?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_Analistas_/_Consultores?=
#  =?UTF-8?Q?_de_Big_Data_(Hadoop)_-_Jun?=
#  =?UTF-8?Q?ior_/_Pleno_na_Etho_Solu=C3=A7=C3=B5es?=
#
# From : NoReply <noreply@o2f-it.com>
#
# Subject : =?iso-8859-1?Q?Processo_de_sele=E7=E3o_em_Amaris?=
#
# From : LinkedIn <jobs-listings@linkedin.com>
#
# Subject : =?UTF-8?Q?Voc=C3=AA_se_candidatou_ao_cargo_de_Desen?=
#  =?UTF-8?Q?volvedor_Python_na_Be_iT_Recruitment?=
#
# From : Felipe Samuel Mendes <invitations@linkedin.com>
#
# Subject : =?UTF-8?Q?Murilo,_voc=C3=AA_poderia_me_adic?=
#  =?UTF-8?Q?ionar_=C3=A0_sua_rede_no_LinkedIn=3F?=
#
# From : Flavio Mennela via LinkedIn <invitations@linkedin.com>
#
# Subject : =?UTF-8?Q?Murilo,_inicie_uma_conversa_com_sua_nova_conex=C3=A3o,_Flavio?=
#
# From : Eduardo Rocha <suporte@cientistadedadosnapratica.com.br>
#
# Subject : Treinamento - Processamento de Dados para Machine Learning
#
# From : Nubank <todomundo@nubank.com.br>
#
# Subject : =?utf-8?q?Conhe=C3=A7a_o_seguro_de_vida_que_cabe_no_seu_bolso=2E?=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-824f16624fff> in <module>
#      42         print(str(e))
#      43
# ---> 44 read_email_from_gmail()
#
# <ipython-input-13-824f16624fff> in read_email_from_gmail()
#      28
#      29         for i in range(latest_email_id,first_email_id, -1):
# ---> 30             data = mail.fetch(str(i), '(RFC822)' )
#      31             for response_part in data:
#      32                 arr = response_part[0]
#
# ~\anaconda3\lib\imaplib.py in fetch(self, message_set, message_parts)
#     532         """
#     533         name = 'FETCH'
# --> 534         typ, dat = self._simple_command(name, message_set, message_parts)
#     535         return self._untagged_response(typ, dat, name)
#     536
#
# ~\anaconda3\lib\imaplib.py in _simple_command(self, name, *args)
#    1194     def _simple_command(self, name, *args):
#    1195
# -> 1196         return self._command_complete(name, self._command(name, *args))
#    1197
#    1198
#
# ~\anaconda3\lib\imaplib.py in _command_complete(self, name, tag)
#    1017             self._check_bye()
#    1018         try:
# -> 1019             typ, data = self._get_tagged_response(tag)
#    1020         except self.abort as val:
#    1021             raise self.abort('command: %s => %s' % (name, val))
#
# ~\anaconda3\lib\imaplib.py in _get_tagged_response(self, tag)
#    1137
#    1138             try:
# -> 1139                 self._get_response()
#    1140             except self.abort as val:
#    1141                 if __debug__:
#
# ~\anaconda3\lib\imaplib.py in _get_response(self)
#    1045         # otherwise first response line received.
#    1046
# -> 1047         resp = self._get_line()
#    1048
#    1049         # Command completion response?
#
# ~\anaconda3\lib\imaplib.py in _get_line(self)
#    1147     def _get_line(self):
#    1148
# -> 1149         line = self.readline()
#    1150         if not line:
#    1151             raise self.abort('socket error: EOF')
#
# ~\anaconda3\lib\imaplib.py in readline(self)
#     308     def readline(self):
#     309         """Read line from remote."""
# --> 310         line = self.file.readline(_MAXLINE + 1)
#     311         if len(line) > _MAXLINE:
#     312             raise self.error("got more than %d bytes" % _MAXLINE)
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
