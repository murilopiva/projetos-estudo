# %% [markdown]
# <h1><center>Segmentação de clientes em shopping</center></h1>

# %% [markdown]
# Problema proposto no kaggle: https://www.kaggle.com/akram24/mall-customers

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scikitplot as skplt
from scipy.spatial import ConvexHull
import numpy as np
from matplotlib.patches import Ellipse

# %% [markdown]
# ### 1. Carregando os dados

# %% [markdown]
# Buscando os dados onlin,e diretamente de um repo github.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/tirthajyoti/Machine-Learning-with-Python/master/Datasets/Mall_Customers.csv")

# %% [markdown]
# Primeira olhada nos dados

# %%
display(df.shape)
df.head()
# Out:
# (200, 5)
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#Verificando Dados Nulos
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# ### 2. Visualizando possíveis agrupamentos

# %% [markdown]
# Visualizando pares de atributos dois a dois.

# %%
fig, ax =plt.subplots(3,1,figsize = (16,16))


sns.scatterplot(data=df, x="Annual Income (k$)", y="Spending Score (1-100)", hue="Gender", ax=ax[0])
sns.scatterplot(data=df, x="Age", y="Spending Score (1-100)", hue="Gender", ax=ax[1])
sns.scatterplot(data=df, x="Age", y="Annual Income (k$)", hue="Gender", ax=ax[2])
fig.show()
# Out:
# C:\Users\User\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   import sys

# %%
# Checa a correlação entre cada um dos atributos (são todos numéricos)
def check_correlation(df): 
    fig, ax = plt.subplots(figsize=(20,8))
    sns.heatmap(
        df.corr(), 
        vmin=-1, vmax=1, center=0,
        cmap=sns.diverging_palette(20, 220, n=200),
        square=True,
        annot = True
    ).set_title('Correlação')
    
    return

# %%
check_correlation(df)

# %% [markdown]
# ### 3. Análise de clusters

# %% [markdown]
# Importando as classes dos algoritmos de agrupamento.

# %%
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

# %% [markdown]
# Executando analises com o K-Means

# %%
def Plot_kmeans(x,y,qtd_cluster):
    df_subset = df[[x, y]].copy()
    kmeans = KMeans(n_clusters=qtd_cluster, random_state=0).fit(df_subset)
    df_subset["Cluster"] = kmeans.labels_

    # get centroids
    centroids = kmeans.cluster_centers_
    cen_x = [i[0] for i in centroids] 
    cen_y = [i[1] for i in centroids]

    fig, ax = plt.subplots(1, figsize=(8,8))
    # plot data
    plt.scatter(df_subset[x], df_subset[y], c=df_subset['Cluster'], alpha = 100, s=15)
    # plot centers
    plt.scatter(cen_x, cen_y, marker='^', s=100)
    # draw enclosure
    plt.xlabel(x)
    plt.ylabel(y)


    for i in df_subset.Cluster.unique():
        points = df_subset[df_subset.Cluster == i][[x, y]].values
        # get convex hull
        hull = ConvexHull(points)
        # get x and y coordinates
        # repeat last point to close the polygon
        x_hull = np.append(points[hull.vertices,0],
                           points[hull.vertices,0][0])
        y_hull = np.append(points[hull.vertices,1],
                           points[hull.vertices,1][0])
        # plot shape
        plt.fill(x_hull, y_hull, alpha=0.3)

# %%
Plot_kmeans('Age', 'Spending Score (1-100)',5)

# %%
Plot_kmeans('Age', 'Annual Income (k$)',5)

# %%
Plot_kmeans('Annual Income (k$)', 'Spending Score (1-100)',5)

# %%
# !pip install the chart-studio
# Out:
# Collecting the
#   Downloading the-0.1.5.tar.gz (10 kB)
# Collecting chart-studio
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: six in c:\users\user\appdata\roaming\python\python37\site-packages (from chart-studio) (1.16.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\user\anaconda3\lib\site-packages (from chart-studio) (1.3.3)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from chart-studio) (2.22.0)
# Requirement already satisfied: plotly in c:\users\user\anaconda3\lib\site-packages (from chart-studio) (4.14.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->chart-studio) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->chart-studio) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->chart-studio) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->chart-studio) (2.8)
# Building wheels for collected packages: the
#   Building wheel for the (setup.py): started
#   Building wheel for the (setup.py): finished with status 'done'
#   Created wheel for the: filename=the-0.1.5-py3-none-any.whl size=6011 sha256=443dd70e818fb46761262f974ea8f5e9d740a70be661dacf9714808001ce1a76
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\f0\9b\76\f019a880f5d490ed05a2425f6b0e2da238502879bd1721d96d
# Successfully built the
# Installing collected packages: the, chart-studio
# Successfully installed chart-studio-1.1.0 the-0.1.5

# %%
from chart_studio.plotly import plot, iplot
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/alpha_shape.csv')
df.head()

scatter = dict(
    mode = "markers",
    name = "y",
    type = "scatter3d",
    x = df['x'], y = df['y'], z = df['z'],
    marker = dict( size=2, color="rgb(23, 190, 207)" )
)
clusters = dict(
    alphahull = 7,
    name = "y",
    opacity = 0.1,
    type = "mesh3d",
    x = df['x'], y = df['y'], z = df['z']
)
layout = dict(
    title = '3d point clustering',
    scene = dict(
        xaxis = dict( zeroline=False ),
        yaxis = dict( zeroline=False ),
        zaxis = dict( zeroline=False ),
    )
)
fig = data=[scatter, clusters], layout=layout
# Use py.iplot() for IPython notebook
#py.iplot(fig, filename='3d point clustering')
#plot(fig, filename='3d point clustering')
#plot.
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a3585a648857> in <module>
#      27     )
#      28 )
# ---> 29 fig = data=[scatter, clusters], layout=layout
#      30 # Use py.iplot() for IPython notebook
#      31 #py.iplot(fig, filename='3d point clustering')
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# Executando analises com o GMM

# %%
df_subset = df[["Age", "Spending Score (1-100)"]].copy()

gm = GaussianMixture(n_components=10, random_state=0).fit(df_subset)
df_subset["Cluster"] =  gm.predict(df_subset)

sns.scatterplot(data=df_subset, x="Age", y="Spending Score (1-100)", hue="Cluster")

# %%
def draw_ellipse(position, covariance, ax=None, **kwargs):
    """Draw an ellipse with a given position and covariance"""
    ax = ax or plt.gca()
    
    # Convert covariance to principal axes
    if covariance.shape == (2, 2):
        U, s, Vt = np.linalg.svd(covariance)
        angle = np.degrees(np.arctan2(U[1, 0], U[0, 0]))
        width, height = 2 * np.sqrt(s)
    else:
        angle = 0
        width, height = 2 * np.sqrt(covariance)
    
    # Draw the Ellipse
    for nsig in range(1, 4):
        ax.add_patch(Ellipse(position, nsig * width, nsig * height,
                             angle, **kwargs))
        
def plot_gmm(x, y,num_comp, label=True, ax=None):
    df_subset = df[[x, y]].copy()
    gm = GaussianMixture(n_components=num_comp, random_state=0).fit(df_subset)
    #ax = ax or plt.gca()
    fig, ax = plt.subplots(1, figsize=(8,8))
    df_subset["Cluster"] =  gm.predict(df_subset)

    ax.scatter(df_subset[x], df_subset[y], c=df_subset["Cluster"], s=40,  zorder=2)
    plt.xlabel(x)
    plt.ylabel(y)

    
    w_factor = 0.2 / gm.weights_.max()
    for pos, covar, w in zip(gm.means_, gm.covariances_, gm.weights_):
        draw_ellipse(pos, covar, alpha=w * w_factor)

# %%
plot_gmm("Age", "Spending Score (1-100)",5)

# %%
plot_gmm("Age", "Annual Income (k$)",5)

# %%
plot_gmm('Annual Income (k$)', 'Spending Score (1-100)',5)

# %% [markdown]
# ### 4. Resultados
