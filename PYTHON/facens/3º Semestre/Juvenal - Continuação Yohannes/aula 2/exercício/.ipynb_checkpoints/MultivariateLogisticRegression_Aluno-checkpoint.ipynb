# %% [markdown]
# <h1><center>Regressão Logística Multivariada</center></h1>

# %% [markdown]
# Nesta aula implementamos as funções necessárias para a construção de um modelo para classificação binária por meio do algorítmo de regressão logística.

# %% [markdown]
# Importando as bibliotecas:

# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import math

np.set_printoptions(precision=8)

# %% [markdown]
# # 1. Implementação

# %% [markdown]
# Funções a serem implementadas no exercício:

# %%
# '''
# ##############################################################################################
# Esta função deve inicializar os parâmetros do modelo de Regressão Logística, sendo o vetor 
# de coeficientes = {m1, m2, m3, ..., mn} do tamanho da quantidade de atributos (n) e o bias um 
# valor escalar. Os resultados devem ser retornados em forma de tupla: (weights, bias).
# ##############################################################################################
# '''
def initialize_weights_bias(x, mode="ones", scale=1):
    try:
        (nlines, ncolumns) = x.shape
    except:    
        ncolumns = 1
        
    if mode == "ones":
        ### ATUALIZE O CÓDIGO ABAIXO ###
        weights = np.ones(shape = ncolumns)    

        weights = weights.reshape(len(weights), 1)
        ### ------------------------ ###
        
    elif mode == "rand":
        np.random.seed(1)
        ### ATUALIZE O CÓDIGO ABAIXO ###
        weights = np.random.random(size = ncolumns)
        weights = weights.reshape(len(weights), 1)
        ### ------------------------ ###

    bias = 0

    return (weights, bias)

# %%
# '''
# ##############################################################################################
# A função de ativação, o sigmoid, é responsável por converter os sinais de entrada para um in-
# tervalo de classificação binária. Para este exercício, assuma que o parâmetro Z já fornece o 
# resultado da parte linear do cálculo, que deve ser ativado pela função logística (1). 
# Dica: Use função np.exp().
# ##############################################################################################
# '''
def sigmoid(z):
    ### ATUALIZE O CÓDIGO ABAIXO ###
    return (1 / (1 + np.exp(-z)))
    ### ------------------------ ###

# %%
# '''
# ##############################################################################################
# Esta funcao deve computar a predicao para cada um dos m registros em x, baseado nos coeficien-
# tes em weights e no bias. Utilize a funcao (1) dos slides.
# Dica: Use a função simoid definida anteriormente.
# ##############################################################################################
# '''
def predict(x, weights, bias):
    ### ATUALIZE O CÓDIGO ABAIXO ###
    z = x.dot(weights) + bias
    
    yhat = sigmoid(z)
    ### ------------------------ ###

    return yhat

# %%
# '''
# ##############################################################################################
# Os resultados da função logística nos indica com qual classe cada um dos registros apresenta
# maior afinidade através de um score entre 0 e 1. Em termos de classificação, contudo, estamos
# interessados em saidas binárias.
# A função abaixo transforma os valores de yhat em predições, usando para isso um limiar de se-
# paração: o threshold.
# ##############################################################################################
# '''
def decision_threshold(yhat_dec):
    threshold = 0.8
    
    #np.where(a < 5, a, 10*a)
    
    ### ATUALIZE O CÓDIGO ABAIXO ###
    y_pred = np.where(yhat_dec > threshold, 1, 0)
    
    ### ------------------------ ###
    
    return y_pred

# %%
# '''
# ##############################################################################################
# Calcula a perda de precisão ocasionada pelo uso do modelo, dada pela diferença entre a predi-
# ção e valor verdadeiro.
# ##############################################################################################
# '''
def loss_function(y, yhat):
    return yhat - y

# %%
# ##############################################################################################
# Coloque aqui o trecho de código que vai calcular o custo gerado pelo modelo. A variável "y" 
# representa o dado real ocorrido, enquanto "yhat" indica as predições. O custo deve ser calcu-
# lado pelo método de Entropia Cruzada. Use a funcao (3) dos slides.
# Dica: use a função np.multiply().
# ##############################################################################################
# '''
def cost_function(y, yhat):
    m = len(y)
    
    ### ATUALIZE O CÓDIGO ABAIXO ###
    #t1 = y.dot(np.log(yhat))
    #t1 = np.dot(y, np.log(yhat), out=None)
    t1 = np.multiply(y, np.log(yhat))
    
    #t2 = (1 - y) * np.log(1 - yhat)
    t2 = np.multiply((1 - y), np.log(1 - yhat))
    
    J = np.sum(-1*(t1+t2))/m
    ### ------------------------ ###

    return J

# %%
# '''
# ##############################################################################################
# Faz uma única atualização de pesos baseado no gradiente gerado pela função de custo.
# ##############################################################################################
# '''
def gradient_descent_single_step(x, y, weights, bias, alpha=0.005):
    m = len(y)
    yhat = predict(x, weights, bias)
    yhat = yhat.reshape(m,1)

    loss = loss_function(y, yhat)
    
    ### ATUALIZE O CÓDIGO ABAIXO ###
    wgradient = (1/m) *  x.T.dot(loss)#função 4
    weights   = weights - wgradient * alpha

    bgradient = (1/m) * np.sum(loss)
    bias      = bias - alpha * bgradient
    ### ------------------------ ###
    
    yhat = predict(x, weights, bias)
    yhat = yhat.reshape(m,1)

    cost = cost_function(y, yhat)

    return (weights, bias, cost)

# %%
# '''
# ##############################################################################################
# Executa o gradiente em modo batch: todos os registros são avaliados antes de a atualiação dos 
# pesos.
# ##############################################################################################
# '''
def batch_gradient_descent(x, y, alpha=0.005, iterations=50):
    m = len(y)
    weights, bias = initialize_weights_bias(x)

    for iteration in range(iterations):
        (weights, bias, cost) = gradient_descent_single_step(x, y, weights, bias, alpha)
        
        if (iterations > 1000):
            if (iteration % 100 == 0):
                print("Gradient descendent iteration %d. Cost = %.8f." %(iteration, cost))
        else:
            print("Gradient descendent iteration %d. Cost = %.8f." %(iteration, cost))

    return weights, bias

# %%
# '''
# ##############################################################################################
# Executa o gradiente com mini subconjuntos de registros entre a base de treino, provendo atuali
# zações mais frequentes.
# ##############################################################################################
# '''
def mini_batch_gradient_descent(x, y, mini_batch_size=64, alpha=0.005, iterations=50):
    m = len(y)
    weights, bias = initialize_weights_bias(x)
    
    n_minibatches = math.floor(m/mini_batch_size)

    for iteration in range(iterations):
        i = 0
        
        while(i < n_minibatches):
            mini_batch_X = x[i * mini_batch_size : ((i+1) * mini_batch_size), :]
            mini_batch_Y = y[i * mini_batch_size : ((i+1) * mini_batch_size), :]
            
            (weights, bias, cost) = gradient_descent_single_step(mini_batch_X, mini_batch_Y, weights, bias, alpha)
            
            print("Gradient descendent iteration %d/ Minibatch %d. Cost = %.8f." %(iteration, i, cost))
            
            i += 1

        # Caso o dataset não seja divisível em porções de mesmo tamanho...
        if m % mini_batch_size != 0:
            ### ATUALIZE O CÓDIGO ABAIXO ###
            mini_batch_X = x[:, n_minibatches * mini_batch_size:]
            mini_batch_Y = y[:, n_minibatches * mini_batch_size:]
            ### ------------------------ ###
            
            (weights, bias, cost) = gradient_descent_single_step(mini_batch_X, mini_batch_Y, weights, bias, alpha)
            
            print("Gradient descendent iteration %d/ Minibatch %d. Cost = %.8f." %(iteration, i, cost))

    yhat = predict(x, weights, bias)
    yhat = yhat.reshape(m,1)
    cost = cost_function(y, yhat)
    
    print("Gradient descendent final cost. Cost = %.8f." %(cost))
    
    return weights, bias

# %%
'''
##############################################################################################
Executa o gradiente para cada registro na base de treino.
Dica: use a função mini_batch_gradient_descent definida anteriormente.
##############################################################################################
'''
def stochastic_gradient_descent(x, y, alpha=0.005, iterations=50):
    m = len(y)
    weights, bias = initialize_weights_bias(x)
    
    ### ATUALIZE O CÓDIGO ABAIXO ###
    None
    ### ------------------------ ###
    
    return weights, bias
# Out:
#   File "<ipython-input-3-a10a78205f37>", line 40
#     return = None
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.1 Teste aqui seu código:
# ----------------------------------------------------------------------------------------------------------------------------
# 1.1 Inicialização de pesos. Resultados esperados:

# %% [markdown]
# ```
# (array([[1.]]), 0)
#
# (array([[1.],
#         [1.]]), 0)
#
# (array([[1.],
#         [1.],
#         [1.],
#         [1.]]), 0)
#
# (array([[2.08511002e-01],
#        [3.60162247e-01],
#        [5.71874087e-05],
#        [1.51166286e-01]]), 0)
# ```

# %%
x1 = np.array([0, 0, 0, 0, 0, 0])
x2 = np.matrix('1 2; 3 4')
x3 = np.matrix('11 12 13 14; 21 22 23 24; 31 32 33 34')

parameters = initialize_weights_bias(x1)
print(parameters)

parameters = initialize_weights_bias(x2)
print(parameters)

parameters = initialize_weights_bias(x3)
print(parameters)

parameters = initialize_weights_bias(x3, mode="rand", scale=0.5)
print(parameters)
# Out:
# (array([[1.]]), 0)
# (array([[1.],
#        [1.]]), 0)
# (array([[1.],
#        [1.],
#        [1.],
#        [1.]]), 0)
# (array([[4.17022005e-01],
#        [7.20324493e-01],
#        [1.14374817e-04],
#        [3.02332573e-01]]), 0)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# 2. Calcule a predição baseado no vetor x e nos parametros.  Resultados esperados:
# ```
#     0.7310585786300049
#
#     [[0.97068777 0.99849882]]
#
#     [[0.99999863 1.         1.        ]]
# ```

# %%
w1 = np.array([0.5])
w2 = np.array([0.5, 1])
w3 = np.array([0.25, 0.25, 0.25, 0.25])

b1 = 1
b2 = 1
b3 = 1

yhat1 = predict(np.array([0]), w1, b1)
yhat2 = predict(x2, w2, b2)
yhat3 = predict(x3, w3, b3)

print(yhat1)
print(yhat2)
print(yhat3)
# Out:
# 0.7310585786300049
# [[0.97068777 0.99849882]]
# [[0.99999863 1.         1.        ]]

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# 3. Teste a funcao de custo. Resultados esperados:
# ```
#     1.541756952565031
# ```

# %%
y = np.array([1, 1, 0, 0, 0, 1])
yhat = np.array([0.99, 0.01, 0.01, 0.01, 0.01, 0.01])

cost = cost_function(y=y, yhat=yhat)
print(cost)
# Out:
# 1.541756952565031

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# 4. Otimize os pesos para os exemplos abaixo. Resultados esperados:
#
# >> Univariada

# %%
# univariada
x1 = np.array([1, 2, 3, 4, 5]).reshape(5,1)
y1 = np.array([1, 1, 1, 0, 0]).reshape(5,1)

weights1, b1 = batch_gradient_descent(x1, y1, alpha=0.05, iterations=2000)
display("Coeficientes:")
display(weights1)
display("Bias:")
display(b1)
# Out:
# Gradient descendent iteration 0. Cost = 1.76329054.
# Gradient descendent iteration 100. Cost = 0.58618393.
# Gradient descendent iteration 200. Cost = 0.49017173.
# Gradient descendent iteration 300. Cost = 0.42411780.
# Gradient descendent iteration 400. Cost = 0.37662386.
# Gradient descendent iteration 500. Cost = 0.34100914.
# Gradient descendent iteration 600. Cost = 0.31331872.
# Gradient descendent iteration 700. Cost = 0.29113178.
# Gradient descendent iteration 800. Cost = 0.27290747.
# Gradient descendent iteration 900. Cost = 0.25762702.
# Gradient descendent iteration 1000. Cost = 0.24459319.
# Gradient descendent iteration 1100. Cost = 0.23331390.
# Gradient descendent iteration 1200. Cost = 0.22343240.
# Gradient descendent iteration 1300. Cost = 0.21468382.
# Gradient descendent iteration 1400. Cost = 0.20686739.
# Gradient descendent iteration 1500. Cost = 0.19982811.
# Gradient descendent iteration 1600. Cost = 0.19344434.
# Gradient descendent iteration 1700. Cost = 0.18761923.
# Gradient descendent iteration 1800. Cost = 0.18227466.
# Gradient descendent iteration 1900. Cost = 0.17734688.
# 'Coeficientes:'
# array([[-1.75649628]])
# 'Bias:'
# 5.911675791476635

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# >> Multivariada

# %%
# multivariada
x2 = np.matrix('1 1; 2 2; 3 3; 4 4')
y2 = np.array([1, 1, 0, 0]).reshape(4,1)

weights2, b2 = mini_batch_gradient_descent(x2, y2, alpha=0.05, iterations=500, mini_batch_size=2)
display("Coeficientes:")
display(weights2)
display("Bias:")
display(b2)
# Out:
# Gradient descendent iteration 0/ Minibatch 0. Cost = 0.07170658.
# Gradient descendent iteration 0/ Minibatch 1. Cost = 5.76144089.
# Gradient descendent iteration 1/ Minibatch 0. Cost = 0.10769460.
# Gradient descendent iteration 1/ Minibatch 1. Cost = 4.54694601.
# Gradient descendent iteration 2/ Minibatch 0. Cost = 0.16122427.
# Gradient descendent iteration 2/ Minibatch 1. Cost = 3.38421937.
# Gradient descendent iteration 3/ Minibatch 0. Cost = 0.23884763.
# Gradient descendent iteration 3/ Minibatch 1. Cost = 2.32973709.
# Gradient descendent iteration 4/ Minibatch 0. Cost = 0.34511232.
# Gradient descendent iteration 4/ Minibatch 1. Cost = 1.47971357.
# Gradient descendent iteration 5/ Minibatch 0. Cost = 0.47540580.
# Gradient descendent iteration 5/ Minibatch 1. Cost = 0.91700213.
# Gradient descendent iteration 6/ Minibatch 0. Cost = 0.60926337.
# Gradient descendent iteration 6/ Minibatch 1. Cost = 0.61218342.
# Gradient descendent iteration 7/ Minibatch 0. Cost = 0.72010976.
# Gradient descendent iteration 7/ Minibatch 1. Cost = 0.45966826.
# Gradient descendent iteration 8/ Minibatch 0. Cost = 0.79771871.
# Gradient descendent iteration 8/ Minibatch 1. Cost = 0.38025738.
# Gradient descendent iteration 9/ Minibatch 0. Cost = 0.84788719.
# Gradient descendent iteration 9/ Minibatch 1. Cost = 0.33575985.
# Gradient descendent iteration 10/ Minibatch 0. Cost = 0.87925608.
# Gradient descendent iteration 10/ Minibatch 1. Cost = 0.30918159.
# Gradient descendent iteration 11/ Minibatch 0. Cost = 0.89832477.
# Gradient descendent iteration 11/ Minibatch 1. Cost = 0.29252493.
# Gradient descendent iteration 12/ Minibatch 0. Cost = 0.90937095.
# Gradient descendent iteration 12/ Minibatch 1. Cost = 0.28170403.
# Gradient descendent iteration 13/ Minibatch 0. Cost = 0.91514945.
# Gradient descendent iteration 13/ Minibatch 1. Cost = 0.27447132.
# Gradient descendent iteration 14/ Minibatch 0. Cost = 0.91744448.
# Gradient descendent iteration 14/ Minibatch 1. Cost = 0.26951564.
# Gradient descendent iteration 15/ Minibatch 0. Cost = 0.91742416.
# Gradient descendent iteration 15/ Minibatch 1. Cost = 0.26603738.
# Gradient descendent iteration 16/ Minibatch 0. Cost = 0.91586095.
# Gradient descendent iteration 16/ Minibatch 1. Cost = 0.26353278.
# Gradient descendent iteration 17/ Minibatch 0. Cost = 0.91326973.
# Gradient descendent iteration 17/ Minibatch 1. Cost = 0.26167692.
# Gradient descendent iteration 18/ Minibatch 0. Cost = 0.90999572.
# Gradient descendent iteration 18/ Minibatch 1. Cost = 0.26025673.
# Gradient descendent iteration 19/ Minibatch 0. Cost = 0.90627139.
# Gradient descendent iteration 19/ Minibatch 1. Cost = 0.25913078.
# Gradient descendent iteration 20/ Minibatch 0. Cost = 0.90225378.
# Gradient descendent iteration 20/ Minibatch 1. Cost = 0.25820444.
# Gradient descendent iteration 21/ Minibatch 0. Cost = 0.89804916.
# Gradient descendent iteration 21/ Minibatch 1. Cost = 0.25741401.
# Gradient descendent iteration 22/ Minibatch 0. Cost = 0.89372960.
# Gradient descendent iteration 22/ Minibatch 1. Cost = 0.25671641.
# Gradient descendent iteration 23/ Minibatch 0. Cost = 0.88934397.
# Gradient descendent iteration 23/ Minibatch 1. Cost = 0.25608242.
# Gradient descendent iteration 24/ Minibatch 0. Cost = 0.88492544.
# Gradient descendent iteration 24/ Minibatch 1. Cost = 0.25549220.
# Gradient descendent iteration 25/ Minibatch 0. Cost = 0.88049649.
# Gradient descendent iteration 25/ Minibatch 1. Cost = 0.25493223.
# Gradient descendent iteration 26/ Minibatch 0. Cost = 0.87607236.
# Gradient descendent iteration 26/ Minibatch 1. Cost = 0.25439330.
# Gradient descendent iteration 27/ Minibatch 0. Cost = 0.87166335.
# Gradient descendent iteration 27/ Minibatch 1. Cost = 0.25386912.
# Gradient descendent iteration 28/ Minibatch 0. Cost = 0.86727638.
# Gradient descendent iteration 28/ Minibatch 1. Cost = 0.25335540.
# Gradient descendent iteration 29/ Minibatch 0. Cost = 0.86291610.
# Gradient descendent iteration 29/ Minibatch 1. Cost = 0.25284921.
# Gradient descendent iteration 30/ Minibatch 0. Cost = 0.85858557.
# Gradient descendent iteration 30/ Minibatch 1. Cost = 0.25234856.
# Gradient descendent iteration 31/ Minibatch 0. Cost = 0.85428679.
# Gradient descendent iteration 31/ Minibatch 1. Cost = 0.25185208.
# Gradient descendent iteration 32/ Minibatch 0. Cost = 0.85002104.
# Gradient descendent iteration 32/ Minibatch 1. Cost = 0.25135883.
# Gradient descendent iteration 33/ Minibatch 0. Cost = 0.84578909.
# Gradient descendent iteration 33/ Minibatch 1. Cost = 0.25086818.
# Gradient descendent iteration 34/ Minibatch 0. Cost = 0.84159138.
# Gradient descendent iteration 34/ Minibatch 1. Cost = 0.25037970.
# Gradient descendent iteration 35/ Minibatch 0. Cost = 0.83742810.
# Gradient descendent iteration 35/ Minibatch 1. Cost = 0.24989309.
# Gradient descendent iteration 36/ Minibatch 0. Cost = 0.83329931.
# Gradient descendent iteration 36/ Minibatch 1. Cost = 0.24940816.
# Gradient descendent iteration 37/ Minibatch 0. Cost = 0.82920493.
# Gradient descendent iteration 37/ Minibatch 1. Cost = 0.24892477.
# Gradient descendent iteration 38/ Minibatch 0. Cost = 0.82514482.
# Gradient descendent iteration 38/ Minibatch 1. Cost = 0.24844285.
# Gradient descendent iteration 39/ Minibatch 0. Cost = 0.82111880.
# Gradient descendent iteration 39/ Minibatch 1. Cost = 0.24796233.
# Gradient descendent iteration 40/ Minibatch 0. Cost = 0.81712663.
# Gradient descendent iteration 40/ Minibatch 1. Cost = 0.24748317.
# Gradient descendent iteration 41/ Minibatch 0. Cost = 0.81316808.
# Gradient descendent iteration 41/ Minibatch 1. Cost = 0.24700536.
# Gradient descendent iteration 42/ Minibatch 0. Cost = 0.80924288.
# Gradient descendent iteration 42/ Minibatch 1. Cost = 0.24652888.
# Gradient descendent iteration 43/ Minibatch 0. Cost = 0.80535076.
# Gradient descendent iteration 43/ Minibatch 1. Cost = 0.24605373.
# Gradient descendent iteration 44/ Minibatch 0. Cost = 0.80149144.
# Gradient descendent iteration 44/ Minibatch 1. Cost = 0.24557991.
# Gradient descendent iteration 45/ Minibatch 0. Cost = 0.79766463.
# Gradient descendent iteration 45/ Minibatch 1. Cost = 0.24510741.
# Gradient descendent iteration 46/ Minibatch 0. Cost = 0.79387005.
# Gradient descendent iteration 46/ Minibatch 1. Cost = 0.24463626.
# Gradient descendent iteration 47/ Minibatch 0. Cost = 0.79010742.
# Gradient descendent iteration 47/ Minibatch 1. Cost = 0.24416644.
# Gradient descendent iteration 48/ Minibatch 0. Cost = 0.78637644.
# Gradient descendent iteration 48/ Minibatch 1. Cost = 0.24369797.
# Gradient descendent iteration 49/ Minibatch 0. Cost = 0.78267684.
# Gradient descendent iteration 49/ Minibatch 1. Cost = 0.24323086.
# Gradient descendent iteration 50/ Minibatch 0. Cost = 0.77900832.
# Gradient descendent iteration 50/ Minibatch 1. Cost = 0.24276510.
# Gradient descendent iteration 51/ Minibatch 0. Cost = 0.77537061.
# Gradient descendent iteration 51/ Minibatch 1. Cost = 0.24230072.
# Gradient descendent iteration 52/ Minibatch 0. Cost = 0.77176342.
# Gradient descendent iteration 52/ Minibatch 1. Cost = 0.24183771.
# Gradient descendent iteration 53/ Minibatch 0. Cost = 0.76818647.
# Gradient descendent iteration 53/ Minibatch 1. Cost = 0.24137608.
# Gradient descendent iteration 54/ Minibatch 0. Cost = 0.76463948.
# Gradient descendent iteration 54/ Minibatch 1. Cost = 0.24091584.
# Gradient descendent iteration 55/ Minibatch 0. Cost = 0.76112217.
# Gradient descendent iteration 55/ Minibatch 1. Cost = 0.24045700.
# Gradient descendent iteration 56/ Minibatch 0. Cost = 0.75763427.
# Gradient descendent iteration 56/ Minibatch 1. Cost = 0.23999956.
# Gradient descendent iteration 57/ Minibatch 0. Cost = 0.75417550.
# Gradient descendent iteration 57/ Minibatch 1. Cost = 0.23954353.
# Gradient descendent iteration 58/ Minibatch 0. Cost = 0.75074559.
# Gradient descendent iteration 58/ Minibatch 1. Cost = 0.23908892.
# Gradient descendent iteration 59/ Minibatch 0. Cost = 0.74734427.
# Gradient descendent iteration 59/ Minibatch 1. Cost = 0.23863572.
# Gradient descendent iteration 60/ Minibatch 0. Cost = 0.74397127.
# Gradient descendent iteration 60/ Minibatch 1. Cost = 0.23818395.
# Gradient descendent iteration 61/ Minibatch 0. Cost = 0.74062633.
# Gradient descendent iteration 61/ Minibatch 1. Cost = 0.23773362.
# Gradient descendent iteration 62/ Minibatch 0. Cost = 0.73730917.
# Gradient descendent iteration 62/ Minibatch 1. Cost = 0.23728472.
# Gradient descendent iteration 63/ Minibatch 0. Cost = 0.73401953.
# Gradient descendent iteration 63/ Minibatch 1. Cost = 0.23683726.
# Gradient descendent iteration 64/ Minibatch 0. Cost = 0.73075716.
# Gradient descendent iteration 64/ Minibatch 1. Cost = 0.23639125.
# Gradient descendent iteration 65/ Minibatch 0. Cost = 0.72752179.
# Gradient descendent iteration 65/ Minibatch 1. Cost = 0.23594669.
# Gradient descendent iteration 66/ Minibatch 0. Cost = 0.72431317.
# Gradient descendent iteration 66/ Minibatch 1. Cost = 0.23550358.
# Gradient descendent iteration 67/ Minibatch 0. Cost = 0.72113104.
# Gradient descendent iteration 67/ Minibatch 1. Cost = 0.23506193.
# Gradient descendent iteration 68/ Minibatch 0. Cost = 0.71797515.
# Gradient descendent iteration 68/ Minibatch 1. Cost = 0.23462175.
# Gradient descendent iteration 69/ Minibatch 0. Cost = 0.71484525.
# Gradient descendent iteration 69/ Minibatch 1. Cost = 0.23418303.
# Gradient descendent iteration 70/ Minibatch 0. Cost = 0.71174108.
# Gradient descendent iteration 70/ Minibatch 1. Cost = 0.23374577.
# Gradient descendent iteration 71/ Minibatch 0. Cost = 0.70866240.
# Gradient descendent iteration 71/ Minibatch 1. Cost = 0.23330999.
# Gradient descendent iteration 72/ Minibatch 0. Cost = 0.70560897.
# Gradient descendent iteration 72/ Minibatch 1. Cost = 0.23287568.
# Gradient descendent iteration 73/ Minibatch 0. Cost = 0.70258054.
# Gradient descendent iteration 73/ Minibatch 1. Cost = 0.23244285.
# Gradient descendent iteration 74/ Minibatch 0. Cost = 0.69957687.
# Gradient descendent iteration 74/ Minibatch 1. Cost = 0.23201150.
# Gradient descendent iteration 75/ Minibatch 0. Cost = 0.69659772.
# Gradient descendent iteration 75/ Minibatch 1. Cost = 0.23158162.
# Gradient descendent iteration 76/ Minibatch 0. Cost = 0.69364285.
# Gradient descendent iteration 76/ Minibatch 1. Cost = 0.23115323.
# Gradient descendent iteration 77/ Minibatch 0. Cost = 0.69071203.
# Gradient descendent iteration 77/ Minibatch 1. Cost = 0.23072633.
# Gradient descendent iteration 78/ Minibatch 0. Cost = 0.68780503.
# Gradient descendent iteration 78/ Minibatch 1. Cost = 0.23030091.
# Gradient descendent iteration 79/ Minibatch 0. Cost = 0.68492161.
# Gradient descendent iteration 79/ Minibatch 1. Cost = 0.22987697.
# Gradient descendent iteration 80/ Minibatch 0. Cost = 0.68206154.
# Gradient descendent iteration 80/ Minibatch 1. Cost = 0.22945452.
# Gradient descendent iteration 81/ Minibatch 0. Cost = 0.67922460.
# Gradient descendent iteration 81/ Minibatch 1. Cost = 0.22903357.
# Gradient descendent iteration 82/ Minibatch 0. Cost = 0.67641056.
# Gradient descendent iteration 82/ Minibatch 1. Cost = 0.22861410.
# Gradient descendent iteration 83/ Minibatch 0. Cost = 0.67361920.
# Gradient descendent iteration 83/ Minibatch 1. Cost = 0.22819612.
# Gradient descendent iteration 84/ Minibatch 0. Cost = 0.67085029.
# Gradient descendent iteration 84/ Minibatch 1. Cost = 0.22777963.
# Gradient descendent iteration 85/ Minibatch 0. Cost = 0.66810363.
# Gradient descendent iteration 85/ Minibatch 1. Cost = 0.22736463.
# Gradient descendent iteration 86/ Minibatch 0. Cost = 0.66537898.
# Gradient descendent iteration 86/ Minibatch 1. Cost = 0.22695112.
# Gradient descendent iteration 87/ Minibatch 0. Cost = 0.66267614.
# Gradient descendent iteration 87/ Minibatch 1. Cost = 0.22653910.
# Gradient descendent iteration 88/ Minibatch 0. Cost = 0.65999489.
# Gradient descendent iteration 88/ Minibatch 1. Cost = 0.22612857.
# Gradient descendent iteration 89/ Minibatch 0. Cost = 0.65733502.
# Gradient descendent iteration 89/ Minibatch 1. Cost = 0.22571953.
# Gradient descendent iteration 90/ Minibatch 0. Cost = 0.65469632.
# Gradient descendent iteration 90/ Minibatch 1. Cost = 0.22531198.
# Gradient descendent iteration 91/ Minibatch 0. Cost = 0.65207858.
# Gradient descendent iteration 91/ Minibatch 1. Cost = 0.22490591.
# Gradient descendent iteration 92/ Minibatch 0. Cost = 0.64948160.
# Gradient descendent iteration 92/ Minibatch 1. Cost = 0.22450133.
# Gradient descendent iteration 93/ Minibatch 0. Cost = 0.64690518.
# Gradient descendent iteration 93/ Minibatch 1. Cost = 0.22409824.
# Gradient descendent iteration 94/ Minibatch 0. Cost = 0.64434911.
# Gradient descendent iteration 94/ Minibatch 1. Cost = 0.22369663.
# Gradient descendent iteration 95/ Minibatch 0. Cost = 0.64181319.
# Gradient descendent iteration 95/ Minibatch 1. Cost = 0.22329650.
# Gradient descendent iteration 96/ Minibatch 0. Cost = 0.63929723.
# Gradient descendent iteration 96/ Minibatch 1. Cost = 0.22289785.
# Gradient descendent iteration 97/ Minibatch 0. Cost = 0.63680102.
# Gradient descendent iteration 97/ Minibatch 1. Cost = 0.22250069.
# Gradient descendent iteration 98/ Minibatch 0. Cost = 0.63432438.
# Gradient descendent iteration 98/ Minibatch 1. Cost = 0.22210500.
# Gradient descendent iteration 99/ Minibatch 0. Cost = 0.63186712.
# Gradient descendent iteration 99/ Minibatch 1. Cost = 0.22171078.
# Gradient descendent iteration 100/ Minibatch 0. Cost = 0.62942904.
# Gradient descendent iteration 100/ Minibatch 1. Cost = 0.22131804.
# Gradient descendent iteration 101/ Minibatch 0. Cost = 0.62700995.
# Gradient descendent iteration 101/ Minibatch 1. Cost = 0.22092677.
# Gradient descendent iteration 102/ Minibatch 0. Cost = 0.62460967.
# Gradient descendent iteration 102/ Minibatch 1. Cost = 0.22053697.
# Gradient descendent iteration 103/ Minibatch 0. Cost = 0.62222801.
# Gradient descendent iteration 103/ Minibatch 1. Cost = 0.22014864.
# Gradient descendent iteration 104/ Minibatch 0. Cost = 0.61986480.
# Gradient descendent iteration 104/ Minibatch 1. Cost = 0.21976177.
# Gradient descendent iteration 105/ Minibatch 0. Cost = 0.61751984.
# Gradient descendent iteration 105/ Minibatch 1. Cost = 0.21937636.
# Gradient descendent iteration 106/ Minibatch 0. Cost = 0.61519297.
# Gradient descendent iteration 106/ Minibatch 1. Cost = 0.21899241.
# Gradient descendent iteration 107/ Minibatch 0. Cost = 0.61288400.
# Gradient descendent iteration 107/ Minibatch 1. Cost = 0.21860991.
# Gradient descendent iteration 108/ Minibatch 0. Cost = 0.61059275.
# Gradient descendent iteration 108/ Minibatch 1. Cost = 0.21822887.
# Gradient descendent iteration 109/ Minibatch 0. Cost = 0.60831906.
# Gradient descendent iteration 109/ Minibatch 1. Cost = 0.21784928.
# Gradient descendent iteration 110/ Minibatch 0. Cost = 0.60606275.
# Gradient descendent iteration 110/ Minibatch 1. Cost = 0.21747113.
# Gradient descendent iteration 111/ Minibatch 0. Cost = 0.60382365.
# Gradient descendent iteration 111/ Minibatch 1. Cost = 0.21709443.
# Gradient descendent iteration 112/ Minibatch 0. Cost = 0.60160160.
# Gradient descendent iteration 112/ Minibatch 1. Cost = 0.21671916.
# Gradient descendent iteration 113/ Minibatch 0. Cost = 0.59939642.
# Gradient descendent iteration 113/ Minibatch 1. Cost = 0.21634534.
# Gradient descendent iteration 114/ Minibatch 0. Cost = 0.59720795.
# Gradient descendent iteration 114/ Minibatch 1. Cost = 0.21597294.
# Gradient descendent iteration 115/ Minibatch 0. Cost = 0.59503603.
# Gradient descendent iteration 115/ Minibatch 1. Cost = 0.21560197.
# Gradient descendent iteration 116/ Minibatch 0. Cost = 0.59288049.
# Gradient descendent iteration 116/ Minibatch 1. Cost = 0.21523243.
# Gradient descendent iteration 117/ Minibatch 0. Cost = 0.59074118.
# Gradient descendent iteration 117/ Minibatch 1. Cost = 0.21486432.
# Gradient descendent iteration 118/ Minibatch 0. Cost = 0.58861794.
# Gradient descendent iteration 118/ Minibatch 1. Cost = 0.21449761.
# Gradient descendent iteration 119/ Minibatch 0. Cost = 0.58651061.
# Gradient descendent iteration 119/ Minibatch 1. Cost = 0.21413233.
# Gradient descendent iteration 120/ Minibatch 0. Cost = 0.58441903.
# Gradient descendent iteration 120/ Minibatch 1. Cost = 0.21376845.
# Gradient descendent iteration 121/ Minibatch 0. Cost = 0.58234305.
# Gradient descendent iteration 121/ Minibatch 1. Cost = 0.21340598.
# Gradient descendent iteration 122/ Minibatch 0. Cost = 0.58028253.
# Gradient descendent iteration 122/ Minibatch 1. Cost = 0.21304491.
# Gradient descendent iteration 123/ Minibatch 0. Cost = 0.57823730.
# Gradient descendent iteration 123/ Minibatch 1. Cost = 0.21268524.
# Gradient descendent iteration 124/ Minibatch 0. Cost = 0.57620722.
# Gradient descendent iteration 124/ Minibatch 1. Cost = 0.21232696.
# Gradient descendent iteration 125/ Minibatch 0. Cost = 0.57419214.
# Gradient descendent iteration 125/ Minibatch 1. Cost = 0.21197007.
# Gradient descendent iteration 126/ Minibatch 0. Cost = 0.57219193.
# Gradient descendent iteration 126/ Minibatch 1. Cost = 0.21161456.
# Gradient descendent iteration 127/ Minibatch 0. Cost = 0.57020642.
# Gradient descendent iteration 127/ Minibatch 1. Cost = 0.21126043.
# Gradient descendent iteration 128/ Minibatch 0. Cost = 0.56823549.
# Gradient descendent iteration 128/ Minibatch 1. Cost = 0.21090768.
# Gradient descendent iteration 129/ Minibatch 0. Cost = 0.56627898.
# Gradient descendent iteration 129/ Minibatch 1. Cost = 0.21055631.
# Gradient descendent iteration 130/ Minibatch 0. Cost = 0.56433677.
# Gradient descendent iteration 130/ Minibatch 1. Cost = 0.21020629.
# Gradient descendent iteration 131/ Minibatch 0. Cost = 0.56240870.
# Gradient descendent iteration 131/ Minibatch 1. Cost = 0.20985764.
# Gradient descendent iteration 132/ Minibatch 0. Cost = 0.56049466.
# Gradient descendent iteration 132/ Minibatch 1. Cost = 0.20951035.
# Gradient descendent iteration 133/ Minibatch 0. Cost = 0.55859449.
# Gradient descendent iteration 133/ Minibatch 1. Cost = 0.20916441.
# Gradient descendent iteration 134/ Minibatch 0. Cost = 0.55670806.
# Gradient descendent iteration 134/ Minibatch 1. Cost = 0.20881982.
# Gradient descendent iteration 135/ Minibatch 0. Cost = 0.55483525.
# Gradient descendent iteration 135/ Minibatch 1. Cost = 0.20847657.
# Gradient descendent iteration 136/ Minibatch 0. Cost = 0.55297593.
# Gradient descendent iteration 136/ Minibatch 1. Cost = 0.20813465.
# Gradient descendent iteration 137/ Minibatch 0. Cost = 0.55112995.
# Gradient descendent iteration 137/ Minibatch 1. Cost = 0.20779407.
# Gradient descendent iteration 138/ Minibatch 0. Cost = 0.54929721.
# Gradient descendent iteration 138/ Minibatch 1. Cost = 0.20745482.
# Gradient descendent iteration 139/ Minibatch 0. Cost = 0.54747755.
# Gradient descendent iteration 139/ Minibatch 1. Cost = 0.20711690.
# Gradient descendent iteration 140/ Minibatch 0. Cost = 0.54567088.
# Gradient descendent iteration 140/ Minibatch 1. Cost = 0.20678029.
# Gradient descendent iteration 141/ Minibatch 0. Cost = 0.54387705.
# Gradient descendent iteration 141/ Minibatch 1. Cost = 0.20644499.
# Gradient descendent iteration 142/ Minibatch 0. Cost = 0.54209594.
# Gradient descendent iteration 142/ Minibatch 1. Cost = 0.20611100.
# Gradient descendent iteration 143/ Minibatch 0. Cost = 0.54032744.
# Gradient descendent iteration 143/ Minibatch 1. Cost = 0.20577832.
# Gradient descendent iteration 144/ Minibatch 0. Cost = 0.53857143.
# Gradient descendent iteration 144/ Minibatch 1. Cost = 0.20544693.
# Gradient descendent iteration 145/ Minibatch 0. Cost = 0.53682777.
# Gradient descendent iteration 145/ Minibatch 1. Cost = 0.20511684.
# Gradient descendent iteration 146/ Minibatch 0. Cost = 0.53509637.
# Gradient descendent iteration 146/ Minibatch 1. Cost = 0.20478804.
# Gradient descendent iteration 147/ Minibatch 0. Cost = 0.53337710.
# Gradient descendent iteration 147/ Minibatch 1. Cost = 0.20446051.
# Gradient descendent iteration 148/ Minibatch 0. Cost = 0.53166984.
# Gradient descendent iteration 148/ Minibatch 1. Cost = 0.20413427.
# Gradient descendent iteration 149/ Minibatch 0. Cost = 0.52997449.
# Gradient descendent iteration 149/ Minibatch 1. Cost = 0.20380930.
# Gradient descendent iteration 150/ Minibatch 0. Cost = 0.52829093.
# Gradient descendent iteration 150/ Minibatch 1. Cost = 0.20348559.
# Gradient descendent iteration 151/ Minibatch 0. Cost = 0.52661904.
# Gradient descendent iteration 151/ Minibatch 1. Cost = 0.20316315.
# Gradient descendent iteration 152/ Minibatch 0. Cost = 0.52495872.
# Gradient descendent iteration 152/ Minibatch 1. Cost = 0.20284196.
# Gradient descendent iteration 153/ Minibatch 0. Cost = 0.52330986.
# Gradient descendent iteration 153/ Minibatch 1. Cost = 0.20252202.
# Gradient descendent iteration 154/ Minibatch 0. Cost = 0.52167236.
# Gradient descendent iteration 154/ Minibatch 1. Cost = 0.20220333.
# Gradient descendent iteration 155/ Minibatch 0. Cost = 0.52004609.
# Gradient descendent iteration 155/ Minibatch 1. Cost = 0.20188588.
# Gradient descendent iteration 156/ Minibatch 0. Cost = 0.51843097.
# Gradient descendent iteration 156/ Minibatch 1. Cost = 0.20156967.
# Gradient descendent iteration 157/ Minibatch 0. Cost = 0.51682688.
# Gradient descendent iteration 157/ Minibatch 1. Cost = 0.20125468.
# Gradient descendent iteration 158/ Minibatch 0. Cost = 0.51523372.
# Gradient descendent iteration 158/ Minibatch 1. Cost = 0.20094092.
# Gradient descendent iteration 159/ Minibatch 0. Cost = 0.51365139.
# Gradient descendent iteration 159/ Minibatch 1. Cost = 0.20062838.
# Gradient descendent iteration 160/ Minibatch 0. Cost = 0.51207979.
# Gradient descendent iteration 160/ Minibatch 1. Cost = 0.20031706.
# Gradient descendent iteration 161/ Minibatch 0. Cost = 0.51051882.
# Gradient descendent iteration 161/ Minibatch 1. Cost = 0.20000694.
# Gradient descendent iteration 162/ Minibatch 0. Cost = 0.50896837.
# Gradient descendent iteration 162/ Minibatch 1. Cost = 0.19969802.
# Gradient descendent iteration 163/ Minibatch 0. Cost = 0.50742836.
# Gradient descendent iteration 163/ Minibatch 1. Cost = 0.19939031.
# Gradient descendent iteration 164/ Minibatch 0. Cost = 0.50589869.
# Gradient descendent iteration 164/ Minibatch 1. Cost = 0.19908378.
# Gradient descendent iteration 165/ Minibatch 0. Cost = 0.50437925.
# Gradient descendent iteration 165/ Minibatch 1. Cost = 0.19877845.
# Gradient descendent iteration 166/ Minibatch 0. Cost = 0.50286995.
# Gradient descendent iteration 166/ Minibatch 1. Cost = 0.19847429.
# Gradient descendent iteration 167/ Minibatch 0. Cost = 0.50137071.
# Gradient descendent iteration 167/ Minibatch 1. Cost = 0.19817131.
# Gradient descendent iteration 168/ Minibatch 0. Cost = 0.49988142.
# Gradient descendent iteration 168/ Minibatch 1. Cost = 0.19786950.
# Gradient descendent iteration 169/ Minibatch 0. Cost = 0.49840200.
# Gradient descendent iteration 169/ Minibatch 1. Cost = 0.19756886.
# Gradient descendent iteration 170/ Minibatch 0. Cost = 0.49693236.
# Gradient descendent iteration 170/ Minibatch 1. Cost = 0.19726938.
# Gradient descendent iteration 171/ Minibatch 0. Cost = 0.49547240.
# Gradient descendent iteration 171/ Minibatch 1. Cost = 0.19697105.
# Gradient descendent iteration 172/ Minibatch 0. Cost = 0.49402204.
# Gradient descendent iteration 172/ Minibatch 1. Cost = 0.19667388.
# Gradient descendent iteration 173/ Minibatch 0. Cost = 0.49258119.
# Gradient descendent iteration 173/ Minibatch 1. Cost = 0.19637784.
# Gradient descendent iteration 174/ Minibatch 0. Cost = 0.49114976.
# Gradient descendent iteration 174/ Minibatch 1. Cost = 0.19608295.
# Gradient descendent iteration 175/ Minibatch 0. Cost = 0.48972767.
# Gradient descendent iteration 175/ Minibatch 1. Cost = 0.19578919.
# Gradient descendent iteration 176/ Minibatch 0. Cost = 0.48831483.
# Gradient descendent iteration 176/ Minibatch 1. Cost = 0.19549656.
# Gradient descendent iteration 177/ Minibatch 0. Cost = 0.48691116.
# Gradient descendent iteration 177/ Minibatch 1. Cost = 0.19520505.
# Gradient descendent iteration 178/ Minibatch 0. Cost = 0.48551657.
# Gradient descendent iteration 178/ Minibatch 1. Cost = 0.19491465.
# Gradient descendent iteration 179/ Minibatch 0. Cost = 0.48413098.
# Gradient descendent iteration 179/ Minibatch 1. Cost = 0.19462537.
# Gradient descendent iteration 180/ Minibatch 0. Cost = 0.48275432.
# Gradient descendent iteration 180/ Minibatch 1. Cost = 0.19433720.
# Gradient descendent iteration 181/ Minibatch 0. Cost = 0.48138649.
# Gradient descendent iteration 181/ Minibatch 1. Cost = 0.19405013.
# Gradient descendent iteration 182/ Minibatch 0. Cost = 0.48002743.
# Gradient descendent iteration 182/ Minibatch 1. Cost = 0.19376415.
# Gradient descendent iteration 183/ Minibatch 0. Cost = 0.47867705.
# Gradient descendent iteration 183/ Minibatch 1. Cost = 0.19347927.
# Gradient descendent iteration 184/ Minibatch 0. Cost = 0.47733527.
# Gradient descendent iteration 184/ Minibatch 1. Cost = 0.19319547.
# Gradient descendent iteration 185/ Minibatch 0. Cost = 0.47600202.
# Gradient descendent iteration 185/ Minibatch 1. Cost = 0.19291275.
# Gradient descendent iteration 186/ Minibatch 0. Cost = 0.47467722.
# Gradient descendent iteration 186/ Minibatch 1. Cost = 0.19263111.
# Gradient descendent iteration 187/ Minibatch 0. Cost = 0.47336079.
# Gradient descendent iteration 187/ Minibatch 1. Cost = 0.19235053.
# Gradient descendent iteration 188/ Minibatch 0. Cost = 0.47205266.
# Gradient descendent iteration 188/ Minibatch 1. Cost = 0.19207102.
# Gradient descendent iteration 189/ Minibatch 0. Cost = 0.47075276.
# Gradient descendent iteration 189/ Minibatch 1. Cost = 0.19179257.
# Gradient descendent iteration 190/ Minibatch 0. Cost = 0.46946102.
# Gradient descendent iteration 190/ Minibatch 1. Cost = 0.19151518.
# Gradient descendent iteration 191/ Minibatch 0. Cost = 0.46817735.
# Gradient descendent iteration 191/ Minibatch 1. Cost = 0.19123883.
# Gradient descendent iteration 192/ Minibatch 0. Cost = 0.46690170.
# Gradient descendent iteration 192/ Minibatch 1. Cost = 0.19096353.
# Gradient descendent iteration 193/ Minibatch 0. Cost = 0.46563398.
# Gradient descendent iteration 193/ Minibatch 1. Cost = 0.19068927.
# Gradient descendent iteration 194/ Minibatch 0. Cost = 0.46437413.
# Gradient descendent iteration 194/ Minibatch 1. Cost = 0.19041604.
# Gradient descendent iteration 195/ Minibatch 0. Cost = 0.46312208.
# Gradient descendent iteration 195/ Minibatch 1. Cost = 0.19014383.
# Gradient descendent iteration 196/ Minibatch 0. Cost = 0.46187776.
# Gradient descendent iteration 196/ Minibatch 1. Cost = 0.18987266.
# Gradient descendent iteration 197/ Minibatch 0. Cost = 0.46064111.
# Gradient descendent iteration 197/ Minibatch 1. Cost = 0.18960249.
# Gradient descendent iteration 198/ Minibatch 0. Cost = 0.45941205.
# Gradient descendent iteration 198/ Minibatch 1. Cost = 0.18933335.
# Gradient descendent iteration 199/ Minibatch 0. Cost = 0.45819051.
# Gradient descendent iteration 199/ Minibatch 1. Cost = 0.18906521.
# Gradient descendent iteration 200/ Minibatch 0. Cost = 0.45697645.
# Gradient descendent iteration 200/ Minibatch 1. Cost = 0.18879807.
# Gradient descendent iteration 201/ Minibatch 0. Cost = 0.45576978.
# Gradient descendent iteration 201/ Minibatch 1. Cost = 0.18853193.
# Gradient descendent iteration 202/ Minibatch 0. Cost = 0.45457044.
# Gradient descendent iteration 202/ Minibatch 1. Cost = 0.18826679.
# Gradient descendent iteration 203/ Minibatch 0. Cost = 0.45337838.
# Gradient descendent iteration 203/ Minibatch 1. Cost = 0.18800263.
# Gradient descendent iteration 204/ Minibatch 0. Cost = 0.45219352.
# Gradient descendent iteration 204/ Minibatch 1. Cost = 0.18773945.
# Gradient descendent iteration 205/ Minibatch 0. Cost = 0.45101581.
# Gradient descendent iteration 205/ Minibatch 1. Cost = 0.18747726.
# Gradient descendent iteration 206/ Minibatch 0. Cost = 0.44984519.
# Gradient descendent iteration 206/ Minibatch 1. Cost = 0.18721603.
# Gradient descendent iteration 207/ Minibatch 0. Cost = 0.44868158.
# Gradient descendent iteration 207/ Minibatch 1. Cost = 0.18695578.
# Gradient descendent iteration 208/ Minibatch 0. Cost = 0.44752494.
# Gradient descendent iteration 208/ Minibatch 1. Cost = 0.18669648.
# Gradient descendent iteration 209/ Minibatch 0. Cost = 0.44637520.
# Gradient descendent iteration 209/ Minibatch 1. Cost = 0.18643815.
# Gradient descendent iteration 210/ Minibatch 0. Cost = 0.44523230.
# Gradient descendent iteration 210/ Minibatch 1. Cost = 0.18618077.
# Gradient descendent iteration 211/ Minibatch 0. Cost = 0.44409619.
# Gradient descendent iteration 211/ Minibatch 1. Cost = 0.18592434.
# Gradient descendent iteration 212/ Minibatch 0. Cost = 0.44296681.
# Gradient descendent iteration 212/ Minibatch 1. Cost = 0.18566885.
# Gradient descendent iteration 213/ Minibatch 0. Cost = 0.44184409.
# Gradient descendent iteration 213/ Minibatch 1. Cost = 0.18541430.
# Gradient descendent iteration 214/ Minibatch 0. Cost = 0.44072799.
# Gradient descendent iteration 214/ Minibatch 1. Cost = 0.18516068.
# Gradient descendent iteration 215/ Minibatch 0. Cost = 0.43961845.
# Gradient descendent iteration 215/ Minibatch 1. Cost = 0.18490799.
# Gradient descendent iteration 216/ Minibatch 0. Cost = 0.43851540.
# Gradient descendent iteration 216/ Minibatch 1. Cost = 0.18465623.
# Gradient descendent iteration 217/ Minibatch 0. Cost = 0.43741881.
# Gradient descendent iteration 217/ Minibatch 1. Cost = 0.18440539.
# Gradient descendent iteration 218/ Minibatch 0. Cost = 0.43632860.
# Gradient descendent iteration 218/ Minibatch 1. Cost = 0.18415546.
# Gradient descendent iteration 219/ Minibatch 0. Cost = 0.43524473.
# Gradient descendent iteration 219/ Minibatch 1. Cost = 0.18390644.
# Gradient descendent iteration 220/ Minibatch 0. Cost = 0.43416715.
# Gradient descendent iteration 220/ Minibatch 1. Cost = 0.18365833.
# Gradient descendent iteration 221/ Minibatch 0. Cost = 0.43309580.
# Gradient descendent iteration 221/ Minibatch 1. Cost = 0.18341112.
# Gradient descendent iteration 222/ Minibatch 0. Cost = 0.43203063.
# Gradient descendent iteration 222/ Minibatch 1. Cost = 0.18316480.
# Gradient descendent iteration 223/ Minibatch 0. Cost = 0.43097159.
# Gradient descendent iteration 223/ Minibatch 1. Cost = 0.18291938.
# Gradient descendent iteration 224/ Minibatch 0. Cost = 0.42991863.
# Gradient descendent iteration 224/ Minibatch 1. Cost = 0.18267485.
# Gradient descendent iteration 225/ Minibatch 0. Cost = 0.42887169.
# Gradient descendent iteration 225/ Minibatch 1. Cost = 0.18243119.
# Gradient descendent iteration 226/ Minibatch 0. Cost = 0.42783073.
# Gradient descendent iteration 226/ Minibatch 1. Cost = 0.18218842.
# Gradient descendent iteration 227/ Minibatch 0. Cost = 0.42679569.
# Gradient descendent iteration 227/ Minibatch 1. Cost = 0.18194652.
# Gradient descendent iteration 228/ Minibatch 0. Cost = 0.42576654.
# Gradient descendent iteration 228/ Minibatch 1. Cost = 0.18170548.
# Gradient descendent iteration 229/ Minibatch 0. Cost = 0.42474321.
# Gradient descendent iteration 229/ Minibatch 1. Cost = 0.18146532.
# Gradient descendent iteration 230/ Minibatch 0. Cost = 0.42372567.
# Gradient descendent iteration 230/ Minibatch 1. Cost = 0.18122601.
# Gradient descendent iteration 231/ Minibatch 0. Cost = 0.42271386.
# Gradient descendent iteration 231/ Minibatch 1. Cost = 0.18098756.
# Gradient descendent iteration 232/ Minibatch 0. Cost = 0.42170773.
# Gradient descendent iteration 232/ Minibatch 1. Cost = 0.18074995.
# Gradient descendent iteration 233/ Minibatch 0. Cost = 0.42070725.
# Gradient descendent iteration 233/ Minibatch 1. Cost = 0.18051320.
# Gradient descendent iteration 234/ Minibatch 0. Cost = 0.41971236.
# Gradient descendent iteration 234/ Minibatch 1. Cost = 0.18027729.
# Gradient descendent iteration 235/ Minibatch 0. Cost = 0.41872302.
# Gradient descendent iteration 235/ Minibatch 1. Cost = 0.18004221.
# Gradient descendent iteration 236/ Minibatch 0. Cost = 0.41773918.
# Gradient descendent iteration 236/ Minibatch 1. Cost = 0.17980797.
# Gradient descendent iteration 237/ Minibatch 0. Cost = 0.41676080.
# Gradient descendent iteration 237/ Minibatch 1. Cost = 0.17957456.
# Gradient descendent iteration 238/ Minibatch 0. Cost = 0.41578784.
# Gradient descendent iteration 238/ Minibatch 1. Cost = 0.17934198.
# Gradient descendent iteration 239/ Minibatch 0. Cost = 0.41482024.
# Gradient descendent iteration 239/ Minibatch 1. Cost = 0.17911021.
# Gradient descendent iteration 240/ Minibatch 0. Cost = 0.41385798.
# Gradient descendent iteration 240/ Minibatch 1. Cost = 0.17887926.
# Gradient descendent iteration 241/ Minibatch 0. Cost = 0.41290099.
# Gradient descendent iteration 241/ Minibatch 1. Cost = 0.17864913.
# Gradient descendent iteration 242/ Minibatch 0. Cost = 0.41194925.
# Gradient descendent iteration 242/ Minibatch 1. Cost = 0.17841980.
# Gradient descendent iteration 243/ Minibatch 0. Cost = 0.41100271.
# Gradient descendent iteration 243/ Minibatch 1. Cost = 0.17819127.
# Gradient descendent iteration 244/ Minibatch 0. Cost = 0.41006133.
# Gradient descendent iteration 244/ Minibatch 1. Cost = 0.17796355.
# Gradient descendent iteration 245/ Minibatch 0. Cost = 0.40912506.
# Gradient descendent iteration 245/ Minibatch 1. Cost = 0.17773662.
# Gradient descendent iteration 246/ Minibatch 0. Cost = 0.40819387.
# Gradient descendent iteration 246/ Minibatch 1. Cost = 0.17751048.
# Gradient descendent iteration 247/ Minibatch 0. Cost = 0.40726771.
# Gradient descendent iteration 247/ Minibatch 1. Cost = 0.17728513.
# Gradient descendent iteration 248/ Minibatch 0. Cost = 0.40634655.
# Gradient descendent iteration 248/ Minibatch 1. Cost = 0.17706057.
# Gradient descendent iteration 249/ Minibatch 0. Cost = 0.40543034.
# Gradient descendent iteration 249/ Minibatch 1. Cost = 0.17683678.
# Gradient descendent iteration 250/ Minibatch 0. Cost = 0.40451905.
# Gradient descendent iteration 250/ Minibatch 1. Cost = 0.17661377.
# Gradient descendent iteration 251/ Minibatch 0. Cost = 0.40361264.
# Gradient descendent iteration 251/ Minibatch 1. Cost = 0.17639153.
# Gradient descendent iteration 252/ Minibatch 0. Cost = 0.40271107.
# Gradient descendent iteration 252/ Minibatch 1. Cost = 0.17617005.
# Gradient descendent iteration 253/ Minibatch 0. Cost = 0.40181429.
# Gradient descendent iteration 253/ Minibatch 1. Cost = 0.17594934.
# Gradient descendent iteration 254/ Minibatch 0. Cost = 0.40092229.
# Gradient descendent iteration 254/ Minibatch 1. Cost = 0.17572939.
# Gradient descendent iteration 255/ Minibatch 0. Cost = 0.40003500.
# Gradient descendent iteration 255/ Minibatch 1. Cost = 0.17551019.
# Gradient descendent iteration 256/ Minibatch 0. Cost = 0.39915241.
# Gradient descendent iteration 256/ Minibatch 1. Cost = 0.17529175.
# Gradient descendent iteration 257/ Minibatch 0. Cost = 0.39827447.
# Gradient descendent iteration 257/ Minibatch 1. Cost = 0.17507405.
# Gradient descendent iteration 258/ Minibatch 0. Cost = 0.39740114.
# Gradient descendent iteration 258/ Minibatch 1. Cost = 0.17485710.
# Gradient descendent iteration 259/ Minibatch 0. Cost = 0.39653239.
# Gradient descendent iteration 259/ Minibatch 1. Cost = 0.17464089.
# Gradient descendent iteration 260/ Minibatch 0. Cost = 0.39566819.
# Gradient descendent iteration 260/ Minibatch 1. Cost = 0.17442541.
# Gradient descendent iteration 261/ Minibatch 0. Cost = 0.39480850.
# Gradient descendent iteration 261/ Minibatch 1. Cost = 0.17421066.
# Gradient descendent iteration 262/ Minibatch 0. Cost = 0.39395328.
# Gradient descendent iteration 262/ Minibatch 1. Cost = 0.17399665.
# Gradient descendent iteration 263/ Minibatch 0. Cost = 0.39310250.
# Gradient descendent iteration 263/ Minibatch 1. Cost = 0.17378336.
# Gradient descendent iteration 264/ Minibatch 0. Cost = 0.39225613.
# Gradient descendent iteration 264/ Minibatch 1. Cost = 0.17357079.
# Gradient descendent iteration 265/ Minibatch 0. Cost = 0.39141413.
# Gradient descendent iteration 265/ Minibatch 1. Cost = 0.17335893.
# Gradient descendent iteration 266/ Minibatch 0. Cost = 0.39057647.
# Gradient descendent iteration 266/ Minibatch 1. Cost = 0.17314779.
# Gradient descendent iteration 267/ Minibatch 0. Cost = 0.38974311.
# Gradient descendent iteration 267/ Minibatch 1. Cost = 0.17293736.
# Gradient descendent iteration 268/ Minibatch 0. Cost = 0.38891402.
# Gradient descendent iteration 268/ Minibatch 1. Cost = 0.17272764.
# Gradient descendent iteration 269/ Minibatch 0. Cost = 0.38808918.
# Gradient descendent iteration 269/ Minibatch 1. Cost = 0.17251862.
# Gradient descendent iteration 270/ Minibatch 0. Cost = 0.38726854.
# Gradient descendent iteration 270/ Minibatch 1. Cost = 0.17231029.
# Gradient descendent iteration 271/ Minibatch 0. Cost = 0.38645208.
# Gradient descendent iteration 271/ Minibatch 1. Cost = 0.17210267.
# Gradient descendent iteration 272/ Minibatch 0. Cost = 0.38563976.
# Gradient descendent iteration 272/ Minibatch 1. Cost = 0.17189573.
# Gradient descendent iteration 273/ Minibatch 0. Cost = 0.38483155.
# Gradient descendent iteration 273/ Minibatch 1. Cost = 0.17168948.
# Gradient descendent iteration 274/ Minibatch 0. Cost = 0.38402743.
# Gradient descendent iteration 274/ Minibatch 1. Cost = 0.17148392.
# Gradient descendent iteration 275/ Minibatch 0. Cost = 0.38322735.
# Gradient descendent iteration 275/ Minibatch 1. Cost = 0.17127904.
# Gradient descendent iteration 276/ Minibatch 0. Cost = 0.38243130.
# Gradient descendent iteration 276/ Minibatch 1. Cost = 0.17107484.
# Gradient descendent iteration 277/ Minibatch 0. Cost = 0.38163923.
# Gradient descendent iteration 277/ Minibatch 1. Cost = 0.17087131.
# Gradient descendent iteration 278/ Minibatch 0. Cost = 0.38085113.
# Gradient descendent iteration 278/ Minibatch 1. Cost = 0.17066845.
# Gradient descendent iteration 279/ Minibatch 0. Cost = 0.38006696.
# Gradient descendent iteration 279/ Minibatch 1. Cost = 0.17046626.
# Gradient descendent iteration 280/ Minibatch 0. Cost = 0.37928669.
# Gradient descendent iteration 280/ Minibatch 1. Cost = 0.17026473.
# Gradient descendent iteration 281/ Minibatch 0. Cost = 0.37851029.
# Gradient descendent iteration 281/ Minibatch 1. Cost = 0.17006387.
# Gradient descendent iteration 282/ Minibatch 0. Cost = 0.37773773.
# Gradient descendent iteration 282/ Minibatch 1. Cost = 0.16986366.
# Gradient descendent iteration 283/ Minibatch 0. Cost = 0.37696899.
# Gradient descendent iteration 283/ Minibatch 1. Cost = 0.16966410.
# Gradient descendent iteration 284/ Minibatch 0. Cost = 0.37620404.
# Gradient descendent iteration 284/ Minibatch 1. Cost = 0.16946520.
# Gradient descendent iteration 285/ Minibatch 0. Cost = 0.37544284.
# Gradient descendent iteration 285/ Minibatch 1. Cost = 0.16926694.
# Gradient descendent iteration 286/ Minibatch 0. Cost = 0.37468538.
# Gradient descendent iteration 286/ Minibatch 1. Cost = 0.16906933.
# Gradient descendent iteration 287/ Minibatch 0. Cost = 0.37393162.
# Gradient descendent iteration 287/ Minibatch 1. Cost = 0.16887236.
# Gradient descendent iteration 288/ Minibatch 0. Cost = 0.37318154.
# Gradient descendent iteration 288/ Minibatch 1. Cost = 0.16867602.
# Gradient descendent iteration 289/ Minibatch 0. Cost = 0.37243510.
# Gradient descendent iteration 289/ Minibatch 1. Cost = 0.16848032.
# Gradient descendent iteration 290/ Minibatch 0. Cost = 0.37169229.
# Gradient descendent iteration 290/ Minibatch 1. Cost = 0.16828525.
# Gradient descendent iteration 291/ Minibatch 0. Cost = 0.37095308.
# Gradient descendent iteration 291/ Minibatch 1. Cost = 0.16809081.
# Gradient descendent iteration 292/ Minibatch 0. Cost = 0.37021744.
# Gradient descendent iteration 292/ Minibatch 1. Cost = 0.16789699.
# Gradient descendent iteration 293/ Minibatch 0. Cost = 0.36948534.
# Gradient descendent iteration 293/ Minibatch 1. Cost = 0.16770379.
# Gradient descendent iteration 294/ Minibatch 0. Cost = 0.36875676.
# Gradient descendent iteration 294/ Minibatch 1. Cost = 0.16751122.
# Gradient descendent iteration 295/ Minibatch 0. Cost = 0.36803167.
# Gradient descendent iteration 295/ Minibatch 1. Cost = 0.16731925.
# Gradient descendent iteration 296/ Minibatch 0. Cost = 0.36731005.
# Gradient descendent iteration 296/ Minibatch 1. Cost = 0.16712790.
# Gradient descendent iteration 297/ Minibatch 0. Cost = 0.36659188.
# Gradient descendent iteration 297/ Minibatch 1. Cost = 0.16693716.
# Gradient descendent iteration 298/ Minibatch 0. Cost = 0.36587712.
# Gradient descendent iteration 298/ Minibatch 1. Cost = 0.16674702.
# Gradient descendent iteration 299/ Minibatch 0. Cost = 0.36516576.
# Gradient descendent iteration 299/ Minibatch 1. Cost = 0.16655749.
# Gradient descendent iteration 300/ Minibatch 0. Cost = 0.36445777.
# Gradient descendent iteration 300/ Minibatch 1. Cost = 0.16636856.
# Gradient descendent iteration 301/ Minibatch 0. Cost = 0.36375312.
# Gradient descendent iteration 301/ Minibatch 1. Cost = 0.16618022.
# Gradient descendent iteration 302/ Minibatch 0. Cost = 0.36305179.
# Gradient descendent iteration 302/ Minibatch 1. Cost = 0.16599248.
# Gradient descendent iteration 303/ Minibatch 0. Cost = 0.36235377.
# Gradient descendent iteration 303/ Minibatch 1. Cost = 0.16580533.
# Gradient descendent iteration 304/ Minibatch 0. Cost = 0.36165901.
# Gradient descendent iteration 304/ Minibatch 1. Cost = 0.16561876.
# Gradient descendent iteration 305/ Minibatch 0. Cost = 0.36096751.
# Gradient descendent iteration 305/ Minibatch 1. Cost = 0.16543278.
# Gradient descendent iteration 306/ Minibatch 0. Cost = 0.36027924.
# Gradient descendent iteration 306/ Minibatch 1. Cost = 0.16524739.
# Gradient descendent iteration 307/ Minibatch 0. Cost = 0.35959417.
# Gradient descendent iteration 307/ Minibatch 1. Cost = 0.16506257.
# Gradient descendent iteration 308/ Minibatch 0. Cost = 0.35891229.
# Gradient descendent iteration 308/ Minibatch 1. Cost = 0.16487833.
# Gradient descendent iteration 309/ Minibatch 0. Cost = 0.35823356.
# Gradient descendent iteration 309/ Minibatch 1. Cost = 0.16469466.
# Gradient descendent iteration 310/ Minibatch 0. Cost = 0.35755798.
# Gradient descendent iteration 310/ Minibatch 1. Cost = 0.16451156.
# Gradient descendent iteration 311/ Minibatch 0. Cost = 0.35688551.
# Gradient descendent iteration 311/ Minibatch 1. Cost = 0.16432903.
# Gradient descendent iteration 312/ Minibatch 0. Cost = 0.35621613.
# Gradient descendent iteration 312/ Minibatch 1. Cost = 0.16414706.
# Gradient descendent iteration 313/ Minibatch 0. Cost = 0.35554983.
# Gradient descendent iteration 313/ Minibatch 1. Cost = 0.16396566.
# Gradient descendent iteration 314/ Minibatch 0. Cost = 0.35488658.
# Gradient descendent iteration 314/ Minibatch 1. Cost = 0.16378482.
# Gradient descendent iteration 315/ Minibatch 0. Cost = 0.35422636.
# Gradient descendent iteration 315/ Minibatch 1. Cost = 0.16360453.
# Gradient descendent iteration 316/ Minibatch 0. Cost = 0.35356915.
# Gradient descendent iteration 316/ Minibatch 1. Cost = 0.16342479.
# Gradient descendent iteration 317/ Minibatch 0. Cost = 0.35291493.
# Gradient descendent iteration 317/ Minibatch 1. Cost = 0.16324561.
# Gradient descendent iteration 318/ Minibatch 0. Cost = 0.35226368.
# Gradient descendent iteration 318/ Minibatch 1. Cost = 0.16306698.
# Gradient descendent iteration 319/ Minibatch 0. Cost = 0.35161538.
# Gradient descendent iteration 319/ Minibatch 1. Cost = 0.16288889.
# Gradient descendent iteration 320/ Minibatch 0. Cost = 0.35097000.
# Gradient descendent iteration 320/ Minibatch 1. Cost = 0.16271134.
# Gradient descendent iteration 321/ Minibatch 0. Cost = 0.35032753.
# Gradient descendent iteration 321/ Minibatch 1. Cost = 0.16253433.
# Gradient descendent iteration 322/ Minibatch 0. Cost = 0.34968794.
# Gradient descendent iteration 322/ Minibatch 1. Cost = 0.16235787.
# Gradient descendent iteration 323/ Minibatch 0. Cost = 0.34905123.
# Gradient descendent iteration 323/ Minibatch 1. Cost = 0.16218193.
# Gradient descendent iteration 324/ Minibatch 0. Cost = 0.34841736.
# Gradient descendent iteration 324/ Minibatch 1. Cost = 0.16200653.
# Gradient descendent iteration 325/ Minibatch 0. Cost = 0.34778632.
# Gradient descendent iteration 325/ Minibatch 1. Cost = 0.16183166.
# Gradient descendent iteration 326/ Minibatch 0. Cost = 0.34715809.
# Gradient descendent iteration 326/ Minibatch 1. Cost = 0.16165731.
# Gradient descendent iteration 327/ Minibatch 0. Cost = 0.34653265.
# Gradient descendent iteration 327/ Minibatch 1. Cost = 0.16148349.
# Gradient descendent iteration 328/ Minibatch 0. Cost = 0.34590998.
# Gradient descendent iteration 328/ Minibatch 1. Cost = 0.16131019.
# Gradient descendent iteration 329/ Minibatch 0. Cost = 0.34529006.
# Gradient descendent iteration 329/ Minibatch 1. Cost = 0.16113741.
# Gradient descendent iteration 330/ Minibatch 0. Cost = 0.34467288.
# Gradient descendent iteration 330/ Minibatch 1. Cost = 0.16096515.
# Gradient descendent iteration 331/ Minibatch 0. Cost = 0.34405842.
# Gradient descendent iteration 331/ Minibatch 1. Cost = 0.16079340.
# Gradient descendent iteration 332/ Minibatch 0. Cost = 0.34344665.
# Gradient descendent iteration 332/ Minibatch 1. Cost = 0.16062217.
# Gradient descendent iteration 333/ Minibatch 0. Cost = 0.34283756.
# Gradient descendent iteration 333/ Minibatch 1. Cost = 0.16045144.
# Gradient descendent iteration 334/ Minibatch 0. Cost = 0.34223113.
# Gradient descendent iteration 334/ Minibatch 1. Cost = 0.16028122.
# Gradient descendent iteration 335/ Minibatch 0. Cost = 0.34162735.
# Gradient descendent iteration 335/ Minibatch 1. Cost = 0.16011151.
# Gradient descendent iteration 336/ Minibatch 0. Cost = 0.34102619.
# Gradient descendent iteration 336/ Minibatch 1. Cost = 0.15994229.
# Gradient descendent iteration 337/ Minibatch 0. Cost = 0.34042764.
# Gradient descendent iteration 337/ Minibatch 1. Cost = 0.15977358.
# Gradient descendent iteration 338/ Minibatch 0. Cost = 0.33983168.
# Gradient descendent iteration 338/ Minibatch 1. Cost = 0.15960536.
# Gradient descendent iteration 339/ Minibatch 0. Cost = 0.33923830.
# Gradient descendent iteration 339/ Minibatch 1. Cost = 0.15943764.
# Gradient descendent iteration 340/ Minibatch 0. Cost = 0.33864747.
# Gradient descendent iteration 340/ Minibatch 1. Cost = 0.15927041.
# Gradient descendent iteration 341/ Minibatch 0. Cost = 0.33805918.
# Gradient descendent iteration 341/ Minibatch 1. Cost = 0.15910367.
# Gradient descendent iteration 342/ Minibatch 0. Cost = 0.33747342.
# Gradient descendent iteration 342/ Minibatch 1. Cost = 0.15893742.
# Gradient descendent iteration 343/ Minibatch 0. Cost = 0.33689016.
# Gradient descendent iteration 343/ Minibatch 1. Cost = 0.15877165.
# Gradient descendent iteration 344/ Minibatch 0. Cost = 0.33630940.
# Gradient descendent iteration 344/ Minibatch 1. Cost = 0.15860637.
# Gradient descendent iteration 345/ Minibatch 0. Cost = 0.33573110.
# Gradient descendent iteration 345/ Minibatch 1. Cost = 0.15844157.
# Gradient descendent iteration 346/ Minibatch 0. Cost = 0.33515527.
# Gradient descendent iteration 346/ Minibatch 1. Cost = 0.15827724.
# Gradient descendent iteration 347/ Minibatch 0. Cost = 0.33458188.
# Gradient descendent iteration 347/ Minibatch 1. Cost = 0.15811339.
# Gradient descendent iteration 348/ Minibatch 0. Cost = 0.33401091.
# Gradient descendent iteration 348/ Minibatch 1. Cost = 0.15795002.
# Gradient descendent iteration 349/ Minibatch 0. Cost = 0.33344236.
# Gradient descendent iteration 349/ Minibatch 1. Cost = 0.15778712.
# Gradient descendent iteration 350/ Minibatch 0. Cost = 0.33287620.
# Gradient descendent iteration 350/ Minibatch 1. Cost = 0.15762468.
# Gradient descendent iteration 351/ Minibatch 0. Cost = 0.33231241.
# Gradient descendent iteration 351/ Minibatch 1. Cost = 0.15746272.
# Gradient descendent iteration 352/ Minibatch 0. Cost = 0.33175100.
# Gradient descendent iteration 352/ Minibatch 1. Cost = 0.15730121.
# Gradient descendent iteration 353/ Minibatch 0. Cost = 0.33119193.
# Gradient descendent iteration 353/ Minibatch 1. Cost = 0.15714017.
# Gradient descendent iteration 354/ Minibatch 0. Cost = 0.33063519.
# Gradient descendent iteration 354/ Minibatch 1. Cost = 0.15697960.
# Gradient descendent iteration 355/ Minibatch 0. Cost = 0.33008077.
# Gradient descendent iteration 355/ Minibatch 1. Cost = 0.15681948.
# Gradient descendent iteration 356/ Minibatch 0. Cost = 0.32952866.
# Gradient descendent iteration 356/ Minibatch 1. Cost = 0.15665981.
# Gradient descendent iteration 357/ Minibatch 0. Cost = 0.32897883.
# Gradient descendent iteration 357/ Minibatch 1. Cost = 0.15650060.
# Gradient descendent iteration 358/ Minibatch 0. Cost = 0.32843128.
# Gradient descendent iteration 358/ Minibatch 1. Cost = 0.15634184.
# Gradient descendent iteration 359/ Minibatch 0. Cost = 0.32788599.
# ...
# Gradient descendent iteration 382/ Minibatch 0. Cost = 0.31593639.
# Gradient descendent iteration 382/ Minibatch 1. Cost = 0.15266187.
# Gradient descendent iteration 383/ Minibatch 0. Cost = 0.31544129.
# Gradient descendent iteration 383/ Minibatch 1. Cost = 0.15251375.
# Gradient descendent iteration 384/ Minibatch 0. Cost = 0.31494811.
# Gradient descendent iteration 384/ Minibatch 1. Cost = 0.15236603.
# Gradient descendent iteration 385/ Minibatch 0. Cost = 0.31445686.
# Gradient descendent iteration 385/ Minibatch 1. Cost = 0.15221871.
# Gradient descendent iteration 386/ Minibatch 0. Cost = 0.31396752.
# Gradient descendent iteration 386/ Minibatch 1. Cost = 0.15207178.
# Gradient descendent iteration 387/ Minibatch 0. Cost = 0.31348008.
# Gradient descendent iteration 387/ Minibatch 1. Cost = 0.15192526.
# Gradient descendent iteration 388/ Minibatch 0. Cost = 0.31299452.
# Gradient descendent iteration 388/ Minibatch 1. Cost = 0.15177912.
# Gradient descendent iteration 389/ Minibatch 0. Cost = 0.31251084.
# Gradient descendent iteration 389/ Minibatch 1. Cost = 0.15163338.
# Gradient descendent iteration 390/ Minibatch 0. Cost = 0.31202903.
# Gradient descendent iteration 390/ Minibatch 1. Cost = 0.15148802.
# Gradient descendent iteration 391/ Minibatch 0. Cost = 0.31154906.
# Gradient descendent iteration 391/ Minibatch 1. Cost = 0.15134306.
# Gradient descendent iteration 392/ Minibatch 0. Cost = 0.31107095.
# Gradient descendent iteration 392/ Minibatch 1. Cost = 0.15119848.
# Gradient descendent iteration 393/ Minibatch 0. Cost = 0.31059466.
# Gradient descendent iteration 393/ Minibatch 1. Cost = 0.15105428.
# Gradient descendent iteration 394/ Minibatch 0. Cost = 0.31012019.
# Gradient descendent iteration 394/ Minibatch 1. Cost = 0.15091047.
# Gradient descendent iteration 395/ Minibatch 0. Cost = 0.30964753.
# Gradient descendent iteration 395/ Minibatch 1. Cost = 0.15076704.
# Gradient descendent iteration 396/ Minibatch 0. Cost = 0.30917668.
# Gradient descendent iteration 396/ Minibatch 1. Cost = 0.15062399.
# Gradient descendent iteration 397/ Minibatch 0. Cost = 0.30870761.
# Gradient descendent iteration 397/ Minibatch 1. Cost = 0.15048131.
# Gradient descendent iteration 398/ Minibatch 0. Cost = 0.30824032.
# Gradient descendent iteration 398/ Minibatch 1. Cost = 0.15033902.
# Gradient descendent iteration 399/ Minibatch 0. Cost = 0.30777479.
# Gradient descendent iteration 399/ Minibatch 1. Cost = 0.15019709.
# Gradient descendent iteration 400/ Minibatch 0. Cost = 0.30731102.
# Gradient descendent iteration 400/ Minibatch 1. Cost = 0.15005554.
# Gradient descendent iteration 401/ Minibatch 0. Cost = 0.30684900.
# Gradient descendent iteration 401/ Minibatch 1. Cost = 0.14991436.
# Gradient descendent iteration 402/ Minibatch 0. Cost = 0.30638872.
# Gradient descendent iteration 402/ Minibatch 1. Cost = 0.14977355.
# Gradient descendent iteration 403/ Minibatch 0. Cost = 0.30593016.
# Gradient descendent iteration 403/ Minibatch 1. Cost = 0.14963311.
# Gradient descendent iteration 404/ Minibatch 0. Cost = 0.30547331.
# Gradient descendent iteration 404/ Minibatch 1. Cost = 0.14949304.
# Gradient descendent iteration 405/ Minibatch 0. Cost = 0.30501818.
# Gradient descendent iteration 405/ Minibatch 1. Cost = 0.14935332.
# Gradient descendent iteration 406/ Minibatch 0. Cost = 0.30456474.
# Gradient descendent iteration 406/ Minibatch 1. Cost = 0.14921398.
# Gradient descendent iteration 407/ Minibatch 0. Cost = 0.30411298.
# Gradient descendent iteration 407/ Minibatch 1. Cost = 0.14907499.
# Gradient descendent iteration 408/ Minibatch 0. Cost = 0.30366290.
# Gradient descendent iteration 408/ Minibatch 1. Cost = 0.14893636.
# Gradient descendent iteration 409/ Minibatch 0. Cost = 0.30321449.
# Gradient descendent iteration 409/ Minibatch 1. Cost = 0.14879809.
# Gradient descendent iteration 410/ Minibatch 0. Cost = 0.30276773.
# Gradient descendent iteration 410/ Minibatch 1. Cost = 0.14866018.
# Gradient descendent iteration 411/ Minibatch 0. Cost = 0.30232263.
# Gradient descendent iteration 411/ Minibatch 1. Cost = 0.14852262.
# Gradient descendent iteration 412/ Minibatch 0. Cost = 0.30187916.
# Gradient descendent iteration 412/ Minibatch 1. Cost = 0.14838542.
# Gradient descendent iteration 413/ Minibatch 0. Cost = 0.30143732.
# Gradient descendent iteration 413/ Minibatch 1. Cost = 0.14824857.
# Gradient descendent iteration 414/ Minibatch 0. Cost = 0.30099709.
# Gradient descendent iteration 414/ Minibatch 1. Cost = 0.14811206.
# Gradient descendent iteration 415/ Minibatch 0. Cost = 0.30055848.
# Gradient descendent iteration 415/ Minibatch 1. Cost = 0.14797591.
# Gradient descendent iteration 416/ Minibatch 0. Cost = 0.30012147.
# Gradient descendent iteration 416/ Minibatch 1. Cost = 0.14784011.
# Gradient descendent iteration 417/ Minibatch 0. Cost = 0.29968605.
# Gradient descendent iteration 417/ Minibatch 1. Cost = 0.14770465.
# Gradient descendent iteration 418/ Minibatch 0. Cost = 0.29925221.
# Gradient descendent iteration 418/ Minibatch 1. Cost = 0.14756953.
# Gradient descendent iteration 419/ Minibatch 0. Cost = 0.29881995.
# Gradient descendent iteration 419/ Minibatch 1. Cost = 0.14743476.
# Gradient descendent iteration 420/ Minibatch 0. Cost = 0.29838925.
# Gradient descendent iteration 420/ Minibatch 1. Cost = 0.14730033.
# Gradient descendent iteration 421/ Minibatch 0. Cost = 0.29796010.
# Gradient descendent iteration 421/ Minibatch 1. Cost = 0.14716624.
# Gradient descendent iteration 422/ Minibatch 0. Cost = 0.29753251.
# Gradient descendent iteration 422/ Minibatch 1. Cost = 0.14703249.
# Gradient descendent iteration 423/ Minibatch 0. Cost = 0.29710645.
# Gradient descendent iteration 423/ Minibatch 1. Cost = 0.14689907.
# Gradient descendent iteration 424/ Minibatch 0. Cost = 0.29668192.
# Gradient descendent iteration 424/ Minibatch 1. Cost = 0.14676599.
# Gradient descendent iteration 425/ Minibatch 0. Cost = 0.29625891.
# Gradient descendent iteration 425/ Minibatch 1. Cost = 0.14663324.
# Gradient descendent iteration 426/ Minibatch 0. Cost = 0.29583741.
# Gradient descendent iteration 426/ Minibatch 1. Cost = 0.14650083.
# Gradient descendent iteration 427/ Minibatch 0. Cost = 0.29541742.
# Gradient descendent iteration 427/ Minibatch 1. Cost = 0.14636875.
# Gradient descendent iteration 428/ Minibatch 0. Cost = 0.29499892.
# Gradient descendent iteration 428/ Minibatch 1. Cost = 0.14623700.
# Gradient descendent iteration 429/ Minibatch 0. Cost = 0.29458191.
# Gradient descendent iteration 429/ Minibatch 1. Cost = 0.14610557.
# Gradient descendent iteration 430/ Minibatch 0. Cost = 0.29416638.
# Gradient descendent iteration 430/ Minibatch 1. Cost = 0.14597448.
# Gradient descendent iteration 431/ Minibatch 0. Cost = 0.29375232.
# Gradient descendent iteration 431/ Minibatch 1. Cost = 0.14584371.
# Gradient descendent iteration 432/ Minibatch 0. Cost = 0.29333972.
# Gradient descendent iteration 432/ Minibatch 1. Cost = 0.14571326.
# Gradient descendent iteration 433/ Minibatch 0. Cost = 0.29292857.
# Gradient descendent iteration 433/ Minibatch 1. Cost = 0.14558314.
# Gradient descendent iteration 434/ Minibatch 0. Cost = 0.29251887.
# Gradient descendent iteration 434/ Minibatch 1. Cost = 0.14545333.
# Gradient descendent iteration 435/ Minibatch 0. Cost = 0.29211061.
# Gradient descendent iteration 435/ Minibatch 1. Cost = 0.14532385.
# Gradient descendent iteration 436/ Minibatch 0. Cost = 0.29170378.
# Gradient descendent iteration 436/ Minibatch 1. Cost = 0.14519469.
# Gradient descendent iteration 437/ Minibatch 0. Cost = 0.29129838.
# Gradient descendent iteration 437/ Minibatch 1. Cost = 0.14506584.
# Gradient descendent iteration 438/ Minibatch 0. Cost = 0.29089438.
# Gradient descendent iteration 438/ Minibatch 1. Cost = 0.14493731.
# Gradient descendent iteration 439/ Minibatch 0. Cost = 0.29049180.
# Gradient descendent iteration 439/ Minibatch 1. Cost = 0.14480910.
# Gradient descendent iteration 440/ Minibatch 0. Cost = 0.29009061.
# Gradient descendent iteration 440/ Minibatch 1. Cost = 0.14468120.
# Gradient descendent iteration 441/ Minibatch 0. Cost = 0.28969081.
# Gradient descendent iteration 441/ Minibatch 1. Cost = 0.14455361.
# Gradient descendent iteration 442/ Minibatch 0. Cost = 0.28929240.
# Gradient descendent iteration 442/ Minibatch 1. Cost = 0.14442633.
# Gradient descendent iteration 443/ Minibatch 0. Cost = 0.28889536.
# Gradient descendent iteration 443/ Minibatch 1. Cost = 0.14429936.
# Gradient descendent iteration 444/ Minibatch 0. Cost = 0.28849970.
# Gradient descendent iteration 444/ Minibatch 1. Cost = 0.14417270.
# Gradient descendent iteration 445/ Minibatch 0. Cost = 0.28810539.
# Gradient descendent iteration 445/ Minibatch 1. Cost = 0.14404635.
# Gradient descendent iteration 446/ Minibatch 0. Cost = 0.28771244.
# Gradient descendent iteration 446/ Minibatch 1. Cost = 0.14392030.
# Gradient descendent iteration 447/ Minibatch 0. Cost = 0.28732083.
# Gradient descendent iteration 447/ Minibatch 1. Cost = 0.14379455.
# Gradient descendent iteration 448/ Minibatch 0. Cost = 0.28693056.
# Gradient descendent iteration 448/ Minibatch 1. Cost = 0.14366911.
# Gradient descendent iteration 449/ Minibatch 0. Cost = 0.28654163.
# Gradient descendent iteration 449/ Minibatch 1. Cost = 0.14354398.
# Gradient descendent iteration 450/ Minibatch 0. Cost = 0.28615402.
# Gradient descendent iteration 450/ Minibatch 1. Cost = 0.14341914.
# Gradient descendent iteration 451/ Minibatch 0. Cost = 0.28576773.
# Gradient descendent iteration 451/ Minibatch 1. Cost = 0.14329460.
# Gradient descendent iteration 452/ Minibatch 0. Cost = 0.28538275.
# Gradient descendent iteration 452/ Minibatch 1. Cost = 0.14317036.
# Gradient descendent iteration 453/ Minibatch 0. Cost = 0.28499907.
# Gradient descendent iteration 453/ Minibatch 1. Cost = 0.14304642.
# Gradient descendent iteration 454/ Minibatch 0. Cost = 0.28461669.
# Gradient descendent iteration 454/ Minibatch 1. Cost = 0.14292277.
# Gradient descendent iteration 455/ Minibatch 0. Cost = 0.28423560.
# Gradient descendent iteration 455/ Minibatch 1. Cost = 0.14279942.
# Gradient descendent iteration 456/ Minibatch 0. Cost = 0.28385580.
# Gradient descendent iteration 456/ Minibatch 1. Cost = 0.14267636.
# Gradient descendent iteration 457/ Minibatch 0. Cost = 0.28347726.
# Gradient descendent iteration 457/ Minibatch 1. Cost = 0.14255359.
# Gradient descendent iteration 458/ Minibatch 0. Cost = 0.28310000.
# Gradient descendent iteration 458/ Minibatch 1. Cost = 0.14243111.
# Gradient descendent iteration 459/ Minibatch 0. Cost = 0.28272400.
# Gradient descendent iteration 459/ Minibatch 1. Cost = 0.14230893.
# Gradient descendent iteration 460/ Minibatch 0. Cost = 0.28234926.
# Gradient descendent iteration 460/ Minibatch 1. Cost = 0.14218703.
# Gradient descendent iteration 461/ Minibatch 0. Cost = 0.28197577.
# Gradient descendent iteration 461/ Minibatch 1. Cost = 0.14206542.
# Gradient descendent iteration 462/ Minibatch 0. Cost = 0.28160352.
# Gradient descendent iteration 462/ Minibatch 1. Cost = 0.14194409.
# Gradient descendent iteration 463/ Minibatch 0. Cost = 0.28123250.
# Gradient descendent iteration 463/ Minibatch 1. Cost = 0.14182305.
# Gradient descendent iteration 464/ Minibatch 0. Cost = 0.28086272.
# Gradient descendent iteration 464/ Minibatch 1. Cost = 0.14170230.
# Gradient descendent iteration 465/ Minibatch 0. Cost = 0.28049416.
# Gradient descendent iteration 465/ Minibatch 1. Cost = 0.14158183.
# Gradient descendent iteration 466/ Minibatch 0. Cost = 0.28012681.
# Gradient descendent iteration 466/ Minibatch 1. Cost = 0.14146163.
# Gradient descendent iteration 467/ Minibatch 0. Cost = 0.27976068.
# Gradient descendent iteration 467/ Minibatch 1. Cost = 0.14134172.
# Gradient descendent iteration 468/ Minibatch 0. Cost = 0.27939575.
# Gradient descendent iteration 468/ Minibatch 1. Cost = 0.14122209.
# Gradient descendent iteration 469/ Minibatch 0. Cost = 0.27903202.
# Gradient descendent iteration 469/ Minibatch 1. Cost = 0.14110274.
# Gradient descendent iteration 470/ Minibatch 0. Cost = 0.27866948.
# Gradient descendent iteration 470/ Minibatch 1. Cost = 0.14098366.
# Gradient descendent iteration 471/ Minibatch 0. Cost = 0.27830812.
# Gradient descendent iteration 471/ Minibatch 1. Cost = 0.14086486.
# Gradient descendent iteration 472/ Minibatch 0. Cost = 0.27794795.
# Gradient descendent iteration 472/ Minibatch 1. Cost = 0.14074634.
# Gradient descendent iteration 473/ Minibatch 0. Cost = 0.27758894.
# Gradient descendent iteration 473/ Minibatch 1. Cost = 0.14062808.
# Gradient descendent iteration 474/ Minibatch 0. Cost = 0.27723111.
# Gradient descendent iteration 474/ Minibatch 1. Cost = 0.14051011.
# Gradient descendent iteration 475/ Minibatch 0. Cost = 0.27687444.
# Gradient descendent iteration 475/ Minibatch 1. Cost = 0.14039240.
# Gradient descendent iteration 476/ Minibatch 0. Cost = 0.27651892.
# Gradient descendent iteration 476/ Minibatch 1. Cost = 0.14027496.
# Gradient descendent iteration 477/ Minibatch 0. Cost = 0.27616455.
# Gradient descendent iteration 477/ Minibatch 1. Cost = 0.14015779.
# Gradient descendent iteration 478/ Minibatch 0. Cost = 0.27581133.
# Gradient descendent iteration 478/ Minibatch 1. Cost = 0.14004089.
# Gradient descendent iteration 479/ Minibatch 0. Cost = 0.27545924.
# Gradient descendent iteration 479/ Minibatch 1. Cost = 0.13992426.
# Gradient descendent iteration 480/ Minibatch 0. Cost = 0.27510828.
# Gradient descendent iteration 480/ Minibatch 1. Cost = 0.13980790.
# Gradient descendent iteration 481/ Minibatch 0. Cost = 0.27475845.
# Gradient descendent iteration 481/ Minibatch 1. Cost = 0.13969180.
# Gradient descendent iteration 482/ Minibatch 0. Cost = 0.27440974.
# Gradient descendent iteration 482/ Minibatch 1. Cost = 0.13957596.
# Gradient descendent iteration 483/ Minibatch 0. Cost = 0.27406215.
# Gradient descendent iteration 483/ Minibatch 1. Cost = 0.13946039.
# Gradient descendent iteration 484/ Minibatch 0. Cost = 0.27371566.
# Gradient descendent iteration 484/ Minibatch 1. Cost = 0.13934508.
# Gradient descendent iteration 485/ Minibatch 0. Cost = 0.27337028.
# Gradient descendent iteration 485/ Minibatch 1. Cost = 0.13923002.
# Gradient descendent iteration 486/ Minibatch 0. Cost = 0.27302599.
# Gradient descendent iteration 486/ Minibatch 1. Cost = 0.13911523.
# Gradient descendent iteration 487/ Minibatch 0. Cost = 0.27268280.
# Gradient descendent iteration 487/ Minibatch 1. Cost = 0.13900070.
# Gradient descendent iteration 488/ Minibatch 0. Cost = 0.27234069.
# Gradient descendent iteration 488/ Minibatch 1. Cost = 0.13888643.
# Gradient descendent iteration 489/ Minibatch 0. Cost = 0.27199967.
# Gradient descendent iteration 489/ Minibatch 1. Cost = 0.13877241.
# Gradient descendent iteration 490/ Minibatch 0. Cost = 0.27165972.
# Gradient descendent iteration 490/ Minibatch 1. Cost = 0.13865865.
# Gradient descendent iteration 491/ Minibatch 0. Cost = 0.27132084.
# Gradient descendent iteration 491/ Minibatch 1. Cost = 0.13854515.
# Gradient descendent iteration 492/ Minibatch 0. Cost = 0.27098303.
# Gradient descendent iteration 492/ Minibatch 1. Cost = 0.13843190.
# Gradient descendent iteration 493/ Minibatch 0. Cost = 0.27064627.
# Gradient descendent iteration 493/ Minibatch 1. Cost = 0.13831890.
# Gradient descendent iteration 494/ Minibatch 0. Cost = 0.27031057.
# Gradient descendent iteration 494/ Minibatch 1. Cost = 0.13820615.
# Gradient descendent iteration 495/ Minibatch 0. Cost = 0.26997592.
# Gradient descendent iteration 495/ Minibatch 1. Cost = 0.13809366.
# Gradient descendent iteration 496/ Minibatch 0. Cost = 0.26964232.
# Gradient descendent iteration 496/ Minibatch 1. Cost = 0.13798141.
# Gradient descendent iteration 497/ Minibatch 0. Cost = 0.26930975.
# Gradient descendent iteration 497/ Minibatch 1. Cost = 0.13786941.
# Gradient descendent iteration 498/ Minibatch 0. Cost = 0.26897821.
# Gradient descendent iteration 498/ Minibatch 1. Cost = 0.13775767.
# Gradient descendent iteration 499/ Minibatch 0. Cost = 0.26864771.
# Gradient descendent iteration 499/ Minibatch 1. Cost = 0.13764617.
# Gradient descendent final cost. Cost = 0.21323629.
# 'Coeficientes:'
# matrix([[-0.90793551],
#         [-0.90793551]])
# 'Bias:'
# 4.111624851428443

# %% [markdown]
# # 2. Aplicação em caso real: Anomalias na coluna vertebral

# %% [markdown]
# O trecho abaixo carrega os dados disponíveis no site http://odds.cs.stonybrook.edu/vertebral-dataset/ sobre análise de anomalias na coluna vertebral de pacientes.

# %%
fname = "vertebral.mat"
mat = loadmat(fname)

X_train, X_test, y_train, y_test = train_test_split(mat['X'], 
                                                    mat['y'], 
                                                    test_size=0.33, 
                                                    random_state=42)

# %% [markdown]
# Calibrando o modelo nos dados de treino:

# %%
w, b = batch_gradient_descent(X_train, y_train, alpha=0.0005, iterations=1800)
# Out:
# Gradient descendent iteration 0. Cost = nan.
# Gradient descendent iteration 100. Cost = 5.23711441.
# Gradient descendent iteration 200. Cost = 2.07835899.
# Gradient descendent iteration 300. Cost = 0.64811627.
# Gradient descendent iteration 400. Cost = 0.44912964.
# Gradient descendent iteration 500. Cost = 0.37042200.
# Gradient descendent iteration 600. Cost = 0.32482986.
# Gradient descendent iteration 700. Cost = 0.30182933.
# Gradient descendent iteration 800. Cost = 0.29135131.
# Gradient descendent iteration 900. Cost = 0.28676990.
# Gradient descendent iteration 1000. Cost = 0.28476268.
# Gradient descendent iteration 1100. Cost = 0.28384808.
# Gradient descendent iteration 1200. Cost = 0.28340355.
# Gradient descendent iteration 1300. Cost = 0.28317107.
# Gradient descendent iteration 1400. Cost = 0.28304101.
# Gradient descendent iteration 1500. Cost = 0.28296414.
# Gradient descendent iteration 1600. Cost = 0.28291674.
# Gradient descendent iteration 1700. Cost = 0.28288651.
# C:\Users\User\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in log
# C:\Users\User\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in multiply

# %% [markdown]
# Predizendo as amostras nos dados de teste:

# %%
yhat = predict(X_test, w, b)
y_pred = decision_threshold(yhat)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-169-de4005e47a6e> in <module>
#       1 yhat = predict(X_test, w, b)
# ----> 2 y_pred = decision_threshold(yhat)
#
# <ipython-input-168-56cf19526c6d> in decision_threshold(yhat_dec)
#      14
#      15     ### ATUALIZE O CÓDIGO ABAIXO ###
# ---> 16     y_pred = np.where(y_pred > threshold, 1, 0)
#      17
#      18     ### ------------------------ ###
#
# UnboundLocalError: local variable 'y_pred' referenced before assignment

# %% [markdown]
# Avaliando as predições pela "Confusion Matrix" e medidas de acurácia.

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[71  0]
#  [ 9  0]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        71
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.89        80
#    macro avg       0.44      0.50      0.47        80
# weighted avg       0.79      0.89      0.83        80
