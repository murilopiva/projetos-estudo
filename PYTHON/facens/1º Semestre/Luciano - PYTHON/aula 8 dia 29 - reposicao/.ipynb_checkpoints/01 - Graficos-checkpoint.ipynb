# %% [markdown]
# # Geração de Gráficos com Matplotlib
#
# ### O Matplotlib é uma biblioteca para a visualização de dados em Python. Ele apresenta uma API orientada a objetos que permite a criação de gráficos em 2D de uma forma simples e com poucos comandos. A ferramenta disponibiliza diversos tipos de gráficos, como em barra, em linha, em pizza, histogramas entre outras opções.
#
# ![](https://matplotlib.org/_static/logo2.png)
#
# ### Há um grande conjunto de funções disponíveis emm _matplotlib.pyplot_ e permitem a criação de figuras, áreas para exibir gráficos, desenhar linhas na área do gráfico, decorar o gráfico com rótulos, etc.

# %% [markdown]
# ### Importando a biblioteca

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math

# %% [markdown]
# ### Diretiva para plotar os gráficos na própria linha

# %%
# %matplotlib inline

# %% [markdown]
# ## Criando e configurando gráficos

# %% [markdown]
# ### Conjunto de dados

# %%
x = np.linspace(0, 5, 11)
y = x**2

# %% [markdown]
# ### Plotando de forma funcional

# %%
plt.plot(x, y)

# %% [markdown]
# ### Alterando parâmetros do gráfico

# %%
plt.plot(x, y, 'r--')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico')
# Out:
# Text(0.5, 1.0, 'Gráfico')

# %% [markdown]
# ### Criando múltiplos gráficos na forma funcional

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico 1')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g*-')
plt.xlabel('Eixo Y')
plt.ylabel('Eixo X')
plt.title('Gráfico 2')
# Out:
# Text(0.5, 1.0, 'Gráfico 2')

# %% [markdown]
# ### Criando plots a partir de Objetos

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x, y)
axes.set_xlabel('Eixo X')
axes.set_ylabel('Eixo Y')
axes.set_title('Gráfico 1')
# Out:
# Text(0.5, 1.0, 'Gráfico 1')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes1.plot(x, y)
axes1.set_xlabel('Eixo X')
axes1.set_ylabel('Eixo Y')
axes1.set_title('Gráfico 1')
axes2 = fig.add_axes([0.2, 0.5, 0.3, 0.3])
axes2.plot(y, x)

# %% [markdown]
# ### Usando o método subplots()

# %%
fig, ax = plt.subplots()

# %%
fig

# %%
ax

# %%
fig, ax = plt.subplots()
ax.plot(x, x**3, 'b-*')
ax.plot(x, x**4, 'g-.')
ax.set_xlabel('Eixo X')
ax.set_ylabel('Eixo Y')
ax.set_title('Gráfico 1')
# Out:
# Text(0.5, 1.0, 'Gráfico 1')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021F8F2ECB88>,
# ...
#       dtype=object)

# %%
ax[0].plot(x, x**3, 'b-*')
ax[0].set_xlabel('Eixo X')
ax[0].set_ylabel('Eixo Y')
ax[0].set_title('Gráfico 1')
ax[1].plot(x, x**4, 'g-.')
ax[1].set_xlabel('Eixo X')
ax[1].set_ylabel('Eixo Y')
ax[1].set_title('Gráfico 2')
fig

# %% [markdown]
# ### Ajuste de layout

# %%
fig, ax = plt.subplots(nrows=5, ncols=5)
plt.tight_layout()

# %% [markdown]
# ### Tamanho da figura

# %%
fig = plt.figure(figsize=(8, 4), dpi=100)

# %%
fig, ax = plt.subplots(figsize=(10, 3))
ax.plot(x, y, 'g')
ax.set_title('Grafico 1')
# Out:
# Text(0.5, 1.0, 'Grafico 1')

# %% [markdown]
# ### Salvando os gráficos

# %%
fig.savefig('g1.png')

# %%
fig.savefig('g1.jpg')

# %% [markdown]
# ### Adicionando legenda

# %%
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(x, y, 'g', label='x^2')
ax.plot(y, x, 'r-.', label='x ** 1/2')
ax.set_title('Grafico 1')
ax.legend()

# %% [markdown]
# ### Cores

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, x**2, color='#FF0000')
ax.plot(x, x**3, 'b--')

# %% [markdown]
# ### Medida

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, x**2, color='#FFAA00', linewidth=6)
ax.plot(x, x**3, 'b--')

# %% [markdown]
# ### Transparência

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, x**2, '#FF0000', lw=5, alpha=.3)
ax.plot(x, x**3, 'b--')

# %% [markdown]
# ### Estilo

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, x**2, '#FF0000', lw=5, alpha=.3, linestyle='-.')
ax.plot(x, x**3, 'b--')

# %% [markdown]
# # Seaborn
#
# ### A biblioteca Seaborn atua em cima do matplotlib e ajuda a melhorar o visual dos gráficos, dando uma aparência mais bem acabada, além de oferecer gráficos estatísticos.

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Plots de Distribuição

# %% [markdown]
# ## distplot
#
# O distplot mostra a distribuição de um conjunto de observações de uma variável.

# %%
sns.distplot(tips['total_bill'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1653dc79dbab> in <module>
# ----> 1 sns.distplot(tips['total_bill'])
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ## jointplot
#
# jointplot() permite combinar basicamente dois distplots() para dados bivariados. pode-se visualizar os dados das seguintes formas (usando o **kind**):
# * scatter
# * reg
# * resid
# * kde
# * hex

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter')
plt.show()

# %%
sns.jointplot(x='tip', y='tip', data=tips, kind='hex')
plt.show()

# %% [markdown]
# ## rugplot
#
# rugplots possuem um conceito muito simples, eles apenas desenham uma marca de traço para cada ponto em uma distribuição univariada. Eles são o bloco de construção de um KDE:

# %%
sns.rugplot(tips['total_bill'])
plt.show()

# %% [markdown]
# ## kdeplot
#
# kdeplots são [Plots de estimativa de densidade kernel](http://en.wikipedia.org/wiki/Kernel_density_estimation#Pratical_estimation_of_the_bandwidth). Plots KDE substituem cada observação com uma distribuição Gaussiana (Normal) centrada em torno desse valor.

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])
plt.show()

# %% [markdown]
# ## Plots categóricos

# %% [markdown]
# ## barplot

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
plt.show()

# %% [markdown]
# ## countplot

# %%
sns.countplot(x='sex', data=tips)
plt.show()

# %% [markdown]
# ## boxplot

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# ## violinplot

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# ## catplot

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='bar')
plt.show()

# %% [markdown]
# ## Plot de regressão

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')
plt.show()

# %%
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)
plt.show()

# %% [markdown]
# ## Plots matriciais

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
pvflights = flights.pivot_table(values='passengers',index='month',columns='year')
pvflights
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(pvflights, cmap='coolwarm')
plt.show()

# %%
sns.heatmap(pvflights, cmap='coolwarm', linecolor='white',linewidths=1)
plt.show()

# %% [markdown]
# ### Paleta de Cores

# %%
sns.palplot(sns.color_palette())

# %%
sns.set_palette('pastel')
sns.palplot(sns.color_palette())

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))

# %%
sns.set_palette(flatui)
sns.palplot(sns.color_palette())

# %%
palettes = ['deep', 'muted', 'pastel', 'bright', 'dark', 'colorblind']
for p in palettes:
    sns.set_palette(p)
    sns.palplot(sns.color_palette())

# %%
plt.plot([0, 1], [0, 1], sns.xkcd_rgb["pale red"], lw=3)
plt.plot([0, 1], [0, 2], sns.xkcd_rgb["medium green"], lw=3)
plt.plot([0, 1], [0, 3], sns.xkcd_rgb["denim blue"], lw=3);

# %%
colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
sns.palplot(sns.xkcd_palette(colors))

# %%
sns.palplot(sns.color_palette("Blues"))
sns.palplot(sns.color_palette("BuGn_r"))
sns.palplot(sns.color_palette("GnBu_d"))
sns.palplot(sns.color_palette("cubehelix", 8))
sns.palplot(sns.cubehelix_palette(8))
sns.palplot(sns.cubehelix_palette(8, start=2, rot=0, dark=0, light=.95, reverse=True))

# %%
sns.set_palette("husl")
x = np.linspace(0, 14, 100)
for i in range(1, 7):
    plt.plot(x, np.sin(x + i * .5) * (7 - i) * 1)

# %%
with sns.color_palette("PuBuGn_d"):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * 1)

# %% [markdown]
# ## Alguns Exemplos Matplotlib

# %% [markdown]
# ### Barras

# %%
x1 = [2, 4, 6, 8, 10]
y1 = [6, 7, 8, 2, 4]
x2 = [1, 3, 5, 7, 9]
y2 = [7, 8, 2, 4, 2]
plt.bar(x1, y1, label = 'Barrar1', color = 'r')
plt.bar(x2, y2, label = 'Barras2', color = 'y')
plt.legend()
plt.show()

# %% [markdown]
# ### Pizza

# %%
pies = [6, 4, 8]
activities = ['X', 'Y', 'Z']
cols = ['r', 'm', 'y']
plt.pie(pies, labels = activities, colors = cols, startangle = 90, shadow = True, explode = (0.1, 0.2, 0))
plt.show()

# %% [markdown]
# ### Dispersão

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [5, 2, 4, 5, 6, 8, 4, 8]
plt.scatter(x, y, label = 'Points', color = 'b', marker = '+', s = 50)
plt.legend()
plt.show()

# %% [markdown]
# ### Histograma

# %%
np.random.seed(19680801)
fig, ax = plt.subplots(figsize=(10, 5))
x = 30*np.random.randn(10000)
mu = x.mean()
median = np.median(x)
sigma = x.std()
textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\mathrm{median}=%.2f$' % (median, ),
    r'$\sigma=%.2f$' % (sigma, )))

ax.hist(x, 50)

# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
plt.show()

# %% [markdown]
# ### Linhas

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()
plt.show()

# %% [markdown]
# ### Multiplos gráficos

# %%
def make_plot(axs):
    box = dict(facecolor='yellow', pad=5, alpha=0.2)

    # Fixing random state for reproducibility
    np.random.seed(19680801)
    ax1 = axs[0, 0]
    ax1.plot(2000*np.random.rand(10))
    ax1.set_title('ylabels not aligned')
    ax1.set_ylabel('misaligned 1', bbox=box)
    ax1.set_ylim(0, 2000)

    ax3 = axs[1, 0]
    ax3.set_ylabel('misaligned 2', bbox=box)
    ax3.plot(np.random.rand(10))

    ax2 = axs[0, 1]
    ax2.set_title('ylabels aligned')
    ax2.plot(2000*np.random.rand(10))
    ax2.set_ylabel('aligned 1', bbox=box)
    ax2.set_ylim(0, 2000)

    ax4 = axs[1, 1]
    ax4.plot(np.random.rand(10))
    ax4.set_ylabel('aligned 2', bbox=box)


# Plot 1:
fig, axs = plt.subplots(2, 2)
fig.subplots_adjust(left=0.2, wspace=0.6)
make_plot(axs)

# just align the last column of axes:
fig.align_ylabels(axs[:, 1])
plt.show()

# %% [markdown]
# ### Box plot e Violin plot

# %%
np.random.seed(19680801)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

# plot violin plot
axes[0].violinplot(all_data,
                   showmeans=False,
                   showmedians=True)
axes[0].set_title('Violin plot')

# plot box plot
axes[1].boxplot(all_data)
axes[1].set_title('Box plot')

# adding horizontal grid lines
for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xticks([y + 1 for y in range(len(all_data))])
    ax.set_xlabel('Four separate samples')
    ax.set_ylabel('Observed values')

# add x-tick labels
plt.setp(axes, xticks=[y + 1 for y in range(len(all_data))], xticklabels=['x1', 'x2', 'x3', 'x4'])
plt.show()

# %% [markdown]
# ### Heatmap

# %%
x=[20,28,15,20,18,25,15,18,18,20,25,30,25,22,30,22,38,40,38,30,22,20,35,33,35]
y=[20,14,15,20,15,20,32,33,45,50,20,20,20,25,30,38,20,28,33,50,48,40,30,35,36]

grid_size=1
h=10

x_min=min(x)
x_max=max(x)
y_min=min(y)
y_max=max(y)

x_grid=np.arange(x_min-h,x_max+h,grid_size)
y_grid=np.arange(y_min-h,y_max+h,grid_size)
x_mesh,y_mesh=np.meshgrid(x_grid,y_grid)

xc=x_mesh+(grid_size/2)
yc=y_mesh+(grid_size/2)

def kde_quartic(d,h):
    dn=d/h
    P=(15/16)*(1-dn**2)**2
    return P

intensity_list=[]
for j in range(len(xc)):
    intensity_row=[]
    for k in range(len(xc[0])):
        kde_value_list=[]
        for i in range(len(x)):
            #CALCULATE DISTANCE
            d=math.sqrt((xc[j][k]-x[i])**2+(yc[j][k]-y[i])**2) 
            if d<=h:
                p=kde_quartic(d,h)
            else:
                p=0
            kde_value_list.append(p)
        #SUM ALL INTENSITY VALUE
        p_total=sum(kde_value_list)
        intensity_row.append(p_total)
    intensity_list.append(intensity_row)

intensity=np.array(intensity_list)
plt.pcolormesh(x_mesh,y_mesh,intensity)
plt.plot(x,y, 'ro')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Alguns Exemplos Seaborn

# %%
sns.set_style("whitegrid")
plt.plot(np.cumsum(np.random.randn(1000,1)))
plt.show()

# %%
sns.set(style="whitegrid", context="talk")
f, ax1 = plt.subplots(1, 1, figsize=(5, 3), sharex=True)

x = np.array(list("ABCDEFGHI"))
y = [1,3,5,4,3,6,8,4,8]

sns.barplot(x, y, palette="BuGn_d", ax=ax1)

ax1.set_ylabel("Sequential")
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.show()

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
sns.set(style="whitegrid")

# Load the example iris dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
plt.show()
