# %% [markdown]
# # Instalando o scrapy

# %%
# !pip install scrapy
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting scrapy
#   Downloading Scrapy-2.4.0-py2.py3-none-any.whl (239 kB)
#      |████████████████████████████████| 239 kB 4.4 MB/s eta 0:00:01
# Collecting itemloaders>=1.0.1
#   Downloading itemloaders-1.0.3-py3-none-any.whl (11 kB)
# Collecting Twisted>=17.9.0
#   Downloading Twisted-20.3.0-cp37-cp37m-manylinux1_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: lxml>=3.5.0; platform_python_implementation == "CPython" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scrapy) (4.5.0)
# Collecting parsel>=1.5.0
#   Downloading parsel-1.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: cryptography>=2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scrapy) (2.8)
# Collecting protego>=0.1.15
#   Downloading Protego-0.1.16.tar.gz (3.2 MB)
#      |████████████████████████████████| 3.2 MB 30.1 MB/s eta 0:00:01
# Collecting cssselect>=0.9.1
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting zope.interface>=4.1.3
#   Downloading zope.interface-5.1.2-cp37-cp37m-manylinux2010_x86_64.whl (237 kB)
#      |████████████████████████████████| 237 kB 30.1 MB/s eta 0:00:01
# Collecting w3lib>=1.17.0
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting itemadapter>=0.1.0
#   Downloading itemadapter-0.1.1-py3-none-any.whl (7.7 kB)
# Collecting queuelib>=1.4.2
#   Downloading queuelib-1.5.0-py2.py3-none-any.whl (13 kB)
# Collecting service-identity>=16.0.0
#   Downloading service_identity-18.1.0-py2.py3-none-any.whl (11 kB)
# Collecting PyDispatcher>=2.0.5
#   Downloading PyDispatcher-2.0.5.tar.gz (34 kB)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scrapy) (19.1.0)
# Collecting jmespath>=0.9.5
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: attrs>=19.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Twisted>=17.9.0->scrapy) (19.3.0)
# Collecting hyperlink>=17.1.1
#   Downloading hyperlink-20.0.1-py2.py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 9.4 MB/s  eta 0:00:01
# Collecting Automat>=0.3.0
#   Downloading Automat-20.2.0-py2.py3-none-any.whl (31 kB)
# Collecting constantly>=15.1
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting PyHamcrest!=1.10.0,>=1.9.0
#   Downloading PyHamcrest-2.0.2-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.7 MB/s  eta 0:00:01
# Collecting incremental>=16.10.1
#   Downloading incremental-17.5.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: six>=1.6.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from parsel>=1.5.0->scrapy) (1.14.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cryptography>=2.0->scrapy) (1.13.2)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from zope.interface>=4.1.3->scrapy) (45.1.0.post20200119)
# Collecting pyasn1-modules
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 27.7 MB/s eta 0:00:01
# Collecting pyasn1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 10.7 MB/s eta 0:00:01
# Requirement already satisfied: idna>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from hyperlink>=17.1.1->Twisted>=17.9.0->scrapy) (2.8)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.0->scrapy) (2.19)
# Building wheels for collected packages: protego, PyDispatcher
#   Building wheel for protego (setup.py) ... done
#   Created wheel for protego: filename=Protego-0.1.16-py3-none-any.whl size=7766 sha256=5583c3f30def8e1cb47bacef1084848d950a802f3eb78e4defeae7daaec204df
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ca/44/01/3592ccfbcfaee4ab297c4097e6e9dbe1c7697e3531a39877ab
#   Building wheel for PyDispatcher (setup.py) ... done
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11513 sha256=e8062bac496e436035f688eb26a9eca370768289efa8aede7e1bcdf12ad1ea06
#   Stored in directory: /home/jovyan/.cache/pip/wheels/dc/d0/bf/0cc715c01fce0bace63b46283acf5cc630d5e5dbb4602c54e5
# Successfully built protego PyDispatcher
# Installing collected packages: itemadapter, w3lib, jmespath, cssselect, parsel, itemloaders, zope.interface, hyperlink, Automat, constantly, PyHamcrest, incremental, Twisted, protego, queuelib, pyasn1, pyasn1-modules, service-identity, PyDispatcher, scrapy
# Successfully installed Automat-20.2.0 PyDispatcher-2.0.5 PyHamcrest-2.0.2 Twisted-20.3.0 constantly-15.1.0 cssselect-1.1.0 hyperlink-20.0.1 incremental-17.5.0 itemadapter-0.1.1 itemloaders-1.0.3 jmespath-0.10.0 parsel-1.6.0 protego-0.1.16 pyasn1-0.4.8 pyasn1-modules-0.2.8 queuelib-1.5.0 scrapy-2.4.0 service-identity-18.1.0 w3lib-1.22.0 zope.interface-5.1.2

# %% [markdown]
# # Criando um projeto scrapy

# %%
# !scrapy startproject helloscrapy
# Out:
# Error: scrapy.cfg already exists in /home/jovyan/labs/helloscrapy

# %%
# !ls

# %%
# !ls helloscrapy

# %%
# !ls helloscrapy/helloscrapy

# %%
# !ls helloscrapy/helloscrapy/spiders

# %% [markdown]
# # Como extrair informações do site abaixo?
# http://quotes.toscrape.com/

# %% [markdown]
# # Criando um novo Spider

# %%
# !cd helloscrapy/helloscrapy/spiders && touch first_spider.py

# %% [markdown]
# # Executando o spider

# %%
# !cd helloscrapy && scrapy crawl spiderone

# %% [markdown]
# # Como extrair informações do site abaixo?
# https://www.americanas.com.br/

# %% [markdown]
# # Executando o spider

# %%
# !cd helloscrapy && scrapy crawl spiderone

# %% [markdown]
# # Arquivo robots.txt
# https://www.amazon.com.br/robots.txt
#
# https://www.americanas.com.br/robots.txt

# %% [markdown]
# # Exercício 1: Coletar página inicial de Games do Mercado Livre

# %%
# !cd helloscrapy && scrapy crawl spiderone

# %% [markdown]
# # Extraíndo informações específicas
# # Scrapy shell, CSS Selector, Xpath, Inspect, SelectorGadget (Chrome)

# %% [markdown]
# ## Scrapy shell
# Digitar no terminal da máquina
# ``` bash
# scrapy shell "http://quotes.toscrape.com/"
# ```

# %% [markdown]
# ## CSS Selector
#
# ``` bash
# response.css('title')
#
# response.css('title').extract()
#
# response.css('title::text').extract()
#
# response.css('title::text')[0].extract() #Se a lista tiver vazia apresenta erro
#
# response.css('title::text').extract_first() #Se não é possível extrair nada do site, retorna NULL como valor (não apresenta erro)
#
# ```

# %% [markdown]
# ## Inspect (Navegador)
# ```bash
# response.css('span.text').extract()
#
# response.css('span.text::text').extract()
#
# response.css('span.text::text')[1].extract()
# ```

# %% [markdown]
# ## Selector Gadget (Google Chrome)
# https://chrome.google.com/webstore/detail/selectorgadget/mhjhnkcfbdhnjickkkdbjoemdmbfginb?hl=pt-BR
#
# ```bash
# Pegnado todos os autores com o selector gadget: .author
#
# response.css('.author::text').extract()
# ```

# %% [markdown]
# ## XPath
# Mais poderosa que os seletores CSS porque pode-se analisar o conteúdo das tags. Ex: selecionar o link que contem o texto "Próxima Página"
#
# ```bash
# response.xpath('//title').extract()
#
# response.xpath('//title/text()').extract()
#
# response.xpath("//span[@class='text']/text()").extract()
#
# response.xpath('//*[contains(concat( " ", @class, " " ), concat( " ", "text", " " ))]/text()').extract() #usando o Selector Gadget
#
# response.xpath("//span[@class='text']/text()")[2].extract()
# ```

# %% [markdown]
# ## Inspect + CSS + Xpath
# Inspecionando o botão "Next"
#
# Extraindo seu conteúdo utilizando os seletores CSS e XPath:
# ```bash
# response.css("li.next a").xpath("@href").extract()
# ```

# %%
# !scrapy shell "http://quotes.toscrape.com/" -c 'response.css("li.next a").xpath("@href").extract()'

# %% [markdown]
# ### Como coletar todas os links desta página?

# %%
# !scrapy shell "http://quotes.toscrape.com/" -c 'response.css("a").xpath("@href").extract()'

# %% [markdown]
# # Extraindo citações e autores
# Alterando o script first_spider

# %%
# !cd helloscrapy && scrapy crawl spiderone
# Out:
# 2020-10-24 16:07:20 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 16:07:20 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 16:07:20 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 16:07:20 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 16:07:20 [scrapy.extensions.telnet] INFO: Telnet Password: c82323a6103921d3
# 2020-10-24 16:07:20 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 16:07:20 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 16:07:20 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 16:07:20 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-10-24 16:07:20 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 16:07:20 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 16:07:20 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 16:07:21 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://quotes.toscrape.com/robots.txt> (referer: None)
# 2020-10-24 16:07:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/> (referer: None)
# 2020-10-24 16:07:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”', '“It is our choices, Harry, that show what we truly are, far more than our abilities.”', '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”', '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”', "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”", '“Try not to become a man of success. Rather become a man of value.”', '“It is better to be hated for what you are than to be loved for what you are not.”', "“I have not failed. I've just found 10,000 ways that won't work.”", "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”", '“A day without sunshine is like, you know, night.”'], 'author': ['Albert Einstein', 'J.K. Rowling', 'Albert Einstein', 'Jane Austen', 'Marilyn Monroe', 'Albert Einstein', 'André Gide', 'Thomas A. Edison', 'Eleanor Roosevelt', 'Steve Martin'], 'tag': ['change', 'deep-thoughts', 'thinking', 'world', 'abilities', 'choices', 'inspirational', 'life', 'live', 'miracle', 'miracles', 'aliteracy', 'books', 'classic', 'humor', 'be-yourself', 'inspirational', 'adulthood', 'success', 'value', 'life', 'love', 'edison', 'failure', 'inspirational', 'paraphrased', 'misattributed-eleanor-roosevelt', 'humor', 'obvious', 'simile']}
# 2020-10-24 16:07:21 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 16:07:21 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 588,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 2557,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 0.569998,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 16, 7, 21, 428055),
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 10,
#  'memusage/max': 54763520,
#  'memusage/startup': 54763520,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 16, 7, 20, 858057)}
# 2020-10-24 16:07:21 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ### Como separar cada citação, author e tag??

# %%
# !cd helloscrapy && scrapy crawl spiderone
# Out:
# 2020-10-24 14:17:35 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 14:17:35 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 14:17:35 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 14:17:35 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 14:17:35 [scrapy.extensions.telnet] INFO: Telnet Password: 8588dc9d6c7fe1c2
# 2020-10-24 14:17:35 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 14:17:35 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 14:17:35 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 14:17:35 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-10-24 14:17:35 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 14:17:35 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 14:17:35 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 14:17:35 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://quotes.toscrape.com/robots.txt> (referer: None)
# 2020-10-24 14:17:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/> (referer: None)
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'], 'author': ['Albert Einstein'], 'tag': ['change', 'deep-thoughts', 'thinking', 'world']}
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“It is our choices, Harry, that show what we truly are, far more than our abilities.”'], 'author': ['J.K. Rowling'], 'tag': ['abilities', 'choices']}
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”'], 'author': ['Albert Einstein'], 'tag': ['inspirational', 'life', 'live', 'miracle', 'miracles']}
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”'], 'author': ['Jane Austen'], 'tag': ['aliteracy', 'books', 'classic', 'humor']}
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ["“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”"], 'author': ['Marilyn Monroe'], 'tag': ['be-yourself', 'inspirational']}
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“Try not to become a man of success. Rather become a man of value.”'], 'author': ['Albert Einstein'], 'tag': ['adulthood', 'success', 'value']}
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“It is better to be hated for what you are than to be loved for what you are not.”'], 'author': ['André Gide'], 'tag': ['life', 'love']}
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ["“I have not failed. I've just found 10,000 ways that won't work.”"], 'author': ['Thomas A. Edison'], 'tag': ['edison', 'failure', 'inspirational', 'paraphrased']}
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ["“A woman is like a tea bag; you never know how strong it is until it's in hot water.”"], 'author': ['Eleanor Roosevelt'], 'tag': ['misattributed-eleanor-roosevelt']}
# 2020-10-24 14:17:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“A day without sunshine is like, you know, night.”'], 'author': ['Steve Martin'], 'tag': ['humor', 'obvious', 'simile']}
# 2020-10-24 14:17:35 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 14:17:35 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 588,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 2557,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 0.548517,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 14, 17, 35, 720739),
#  'item_scraped_count': 10,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 10,
#  'memusage/max': 54923264,
#  'memusage/startup': 54923264,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 14, 17, 35, 172222)}
# 2020-10-24 14:17:35 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Exercício 2: Coletar os nomes dos produtos na primeira página do Mercado Livre Games

# %%
# !cd helloscrapy && scrapy crawl spiderone
# Out:
# 2020-10-24 14:18:19 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 14:18:19 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 14:18:19 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 14:18:19 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 14:18:19 [scrapy.extensions.telnet] INFO: Telnet Password: 42ba00075417a7ca
# 2020-10-24 14:18:19 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 14:18:19 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 14:18:19 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 14:18:19 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-10-24 14:18:19 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 14:18:19 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 14:18:19 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 14:18:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://games.mercadolivre.com.br/robots.txt> (referer: None)
# 2020-10-24 14:18:24 [scrapy.robotstxt] WARNING: Failure while parsing robots.txt. File either contains garbage or is in an encoding other than UTF-8, treating it as an empty file.
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/twisted/internet/defer.py", line 1418, in _inlineCallbacks
#     result = g.send(result)
# StopIteration: <200 https://games.mercadolivre.com.br/robots.txt>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/scrapy/robotstxt.py", line 16, in decode_robotstxt
#     robotstxt_body = robotstxt_body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2876: invalid continuation byte
# 2020-10-24 14:18:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://games.mercadolivre.com.br/games/> (referer: None)
# 2020-10-24 14:18:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'title': ['Fone de ouvido gamer Tedge  preto', 'Super Mini Sfc Retrô 620 Jogos 2 Controles Envio Imediato Rj', 'Mini Game Retrô Portatil 400 Jogos Antigos Anos 80 Promoção', 'Super Mini Game Lcd 3  400 Jogos Portátil Av C/ Controle ', 'Mini Video Game Portatil Retrô + 3.000 Jogos Super Nintendo', 'Xbox 360 Slim + Kinect + Jogo Adventures', 'Jogo The Last Of Us Part Ii - Ps4 Sony', 'Ps4 Grand Theft Auto V 5 Gta 5 Mídia Física Novo Português', 'Super Nintendo Mini 8 Mil Jogos 2 Controles Envio Imediato!', 'Fone De Ouvido Headset Gamer Microfone P2 Tedge', 'The Last Of Us Part 2 Midia Fisica Pronta Entrega Pt-br + Nf', 'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles.', 'Xbox One S 1tb 4k  All Digital Novo Lacrado 12x S/j', 'Fone Headset Gamer 7.1hd Led Mic  Usb P2 Xbox Ps4 Pc Celular', 'Cockpit Suporte Volante Simulador Logitech G29/920/ps4 Sgt', 'Pes 2020 Ps4 Mídia Fisica Pronta Entrega + Nf', 'Mini Video Game Portatil 400 Jogos Tv Classico - Ax', 'Ps4 Grand Theft Auto V 5 Gta 5 Mídia Física Novo Português', 'Playstation 2 + 2 Controle + 1 Memory Card + Brinde 4 Jogos', 'Headphone Gamer Bass Haiz- 1804 Com Fio Corda Microfone', 'Cabo Flat Tipo J Play2 Para O Leitor Série 9000x 7000x Slim', 'Playstation 2+ 2 Controle + 1 M.card + Pen Driver 32gb-opl!', 'Vídeo Game Portátil Sup Game Boy 400 Jogos Retro Clássico Nes Gba Sega Controle Multiplayer Ligue Tv', 'Pes 2021ps4 Efootball Pro Evolution Soccer + Brinde Oferta', 'Console Xbox One S 1tb 4k Ultra Hd Original Lacrado Com Nf-e', 'Carregador Controle Ps4 Com Filtro Usb V8 Feir Original', 'Pes 2021 Efootball Pro Evolution Soccer Ps4 Midia Fisica+nf', 'Chave Mini Torx T8 Com Furo Ps3 Ps4 Controle Xbox 360 One', 'Playstation 2 + 2 Controle + 1 Memory Card + Jogo+ Garantia!', 'Fone Gamer Headset Microfone 7.1 Auricular Hd Pc Ps4 Xbox ', 'Video Game Portátil Vários Jogos Nes Nintendo Sega Gba Mp3', 'Xbox One S 1tb 4k  All Digital Novo Lacrado 12x S/j', 'Headset Gamer Redragon Scylla P2 Preto H901', 'Mini Game Retrô Portatil 400 Jogos Antigos Anos 80 Promoção', '2 Bateria E Cabo Xbox One Carregador Charge Controle ', 'Carregador Controle Ps4 Base Duplo Charge Para Playstation 4', 'The Last Of Us 2 Ps4 Mídia Física Novo Pronta Entrega', 'Super Mini Game Portátil 132 In 1 Modelo Retro', 'Super Mini Game Portátil 132 In 1 Brinck Game Modelo Antigo', 'Jogo Call Of Duty Black Ops 4 - Cod Bo4 Ps4', 'Ghost Of Tsushima Ps4 Mídia Física Novo Pronta Entrega', 'Headphone Gamer Deneb 1802 Luz Led Fio Corda E Microfone ', 'Mini Game Retrô Anos Vários Jogos Cobra Corrida Tetris', 'Pes 2021 Pes 21 Ps4 Mídia Física - Lacrado - Português Novo', 'Video Game Retro Box Com Jogos Clássicos 64gb Super Barato', 'Mini Game Retrô Portátil Com Controle 400 Jogos - Sup', 'Gta 5 Grand Theft Auto Gta V Xbox 360 Mídia Física Lacrado!', 'Playstation 2 + 2 Controle + 1 Memory Card + Brinde', 'Mini Video Game Portatil Retrô + 3.000 Jogos Super Nintendo', 'Controle Sem Fio Dualshock 4 Sony Ps4 - Preto', 'Console Ps4 Playstation 4 500gb Slim Lacrado Original E Nf-e']}
# 2020-10-24 14:18:25 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 14:18:25 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 660,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 83886,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 6.026326,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 14, 18, 25, 752972),
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 54657024,
#  'memusage/startup': 54657024,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 14, 18, 19, 726646)}
# 2020-10-24 14:18:25 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Item containers
# Extracted data > Temporary containers > Store in database

# %% [markdown]
# ## Alterando o arquivo items.py
# Declarando title, author e tag; Importando o arquivo items.py no Spider

# %%
# !cd helloscrapy && scrapy crawl spiderone
# Out:
# 2020-10-24 14:38:23 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 14:38:23 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 14:38:23 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 14:38:23 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 14:38:23 [scrapy.extensions.telnet] INFO: Telnet Password: 872d2fcd94a84d10
# 2020-10-24 14:38:23 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 14:38:23 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 14:38:23 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 14:38:23 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-10-24 14:38:23 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 14:38:23 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 14:38:23 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 14:38:23 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://quotes.toscrape.com/robots.txt> (referer: None)
# 2020-10-24 14:38:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/> (referer: None)
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['change', 'deep-thoughts', 'thinking', 'world'],
#  'title': ['“The world as we have created it is a process of our thinking. It '
#            'cannot be changed without changing our thinking.”']}
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['J.K. Rowling'],
#  'tag': ['abilities', 'choices'],
#  'title': ['“It is our choices, Harry, that show what we truly are, far more '
#            'than our abilities.”']}
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['inspirational', 'life', 'live', 'miracle', 'miracles'],
#  'title': ['“There are only two ways to live your life. One is as though '
#            'nothing is a miracle. The other is as though everything is a '
#            'miracle.”']}
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Jane Austen'],
#  'tag': ['aliteracy', 'books', 'classic', 'humor'],
#  'title': ['“The person, be it gentleman or lady, who has not pleasure in a '
#            'good novel, must be intolerably stupid.”']}
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Marilyn Monroe'],
#  'tag': ['be-yourself', 'inspirational'],
#  'title': ["“Imperfection is beauty, madness is genius and it's better to be "
#            'absolutely ridiculous than absolutely boring.”']}
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['adulthood', 'success', 'value'],
#  'title': ['“Try not to become a man of success. Rather become a man of '
#            'value.”']}
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['André Gide'],
#  'tag': ['life', 'love'],
#  'title': ['“It is better to be hated for what you are than to be loved for '
#            'what you are not.”']}
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Thomas A. Edison'],
#  'tag': ['edison', 'failure', 'inspirational', 'paraphrased'],
#  'title': ["“I have not failed. I've just found 10,000 ways that won't work.”"]}
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Eleanor Roosevelt'],
#  'tag': ['misattributed-eleanor-roosevelt'],
#  'title': ['“A woman is like a tea bag; you never know how strong it is until '
#            "it's in hot water.”"]}
# 2020-10-24 14:38:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Steve Martin'],
#  'tag': ['humor', 'obvious', 'simile'],
#  'title': ['“A day without sunshine is like, you know, night.”']}
# 2020-10-24 14:38:24 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 14:38:24 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 588,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 2561,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 0.551425,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 14, 38, 24, 264648),
#  'item_scraped_count': 10,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 10,
#  'memusage/max': 54579200,
#  'memusage/startup': 54579200,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 14, 38, 23, 713223)}
# 2020-10-24 14:38:24 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Armazenando o resultado em arquivos JSON

# %%
# !cd helloscrapy && scrapy crawl spiderone -o items.json
# Out:
# 2020-10-24 14:39:08 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 14:39:08 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 14:39:08 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 14:39:08 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 14:39:08 [scrapy.extensions.telnet] INFO: Telnet Password: 30cc0ed1faee41c0
# 2020-10-24 14:39:08 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 14:39:08 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 14:39:08 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 14:39:08 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-10-24 14:39:08 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 14:39:08 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 14:39:08 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 14:39:08 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://quotes.toscrape.com/robots.txt> (referer: None)
# 2020-10-24 14:39:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/> (referer: None)
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['change', 'deep-thoughts', 'thinking', 'world'],
#  'title': ['“The world as we have created it is a process of our thinking. It '
#            'cannot be changed without changing our thinking.”']}
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['J.K. Rowling'],
#  'tag': ['abilities', 'choices'],
#  'title': ['“It is our choices, Harry, that show what we truly are, far more '
#            'than our abilities.”']}
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['inspirational', 'life', 'live', 'miracle', 'miracles'],
#  'title': ['“There are only two ways to live your life. One is as though '
#            'nothing is a miracle. The other is as though everything is a '
#            'miracle.”']}
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Jane Austen'],
#  'tag': ['aliteracy', 'books', 'classic', 'humor'],
#  'title': ['“The person, be it gentleman or lady, who has not pleasure in a '
#            'good novel, must be intolerably stupid.”']}
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Marilyn Monroe'],
#  'tag': ['be-yourself', 'inspirational'],
#  'title': ["“Imperfection is beauty, madness is genius and it's better to be "
#            'absolutely ridiculous than absolutely boring.”']}
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['adulthood', 'success', 'value'],
#  'title': ['“Try not to become a man of success. Rather become a man of '
#            'value.”']}
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['André Gide'],
#  'tag': ['life', 'love'],
#  'title': ['“It is better to be hated for what you are than to be loved for '
#            'what you are not.”']}
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Thomas A. Edison'],
#  'tag': ['edison', 'failure', 'inspirational', 'paraphrased'],
#  'title': ["“I have not failed. I've just found 10,000 ways that won't work.”"]}
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Eleanor Roosevelt'],
#  'tag': ['misattributed-eleanor-roosevelt'],
#  'title': ['“A woman is like a tea bag; you never know how strong it is until '
#            "it's in hot water.”"]}
# 2020-10-24 14:39:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Steve Martin'],
#  'tag': ['humor', 'obvious', 'simile'],
#  'title': ['“A day without sunshine is like, you know, night.”']}
# 2020-10-24 14:39:08 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 14:39:08 [scrapy.extensions.feedexport] INFO: Stored json feed (10 items) in: items.json
# 2020-10-24 14:39:08 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 588,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 2561,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 0.565942,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 14, 39, 8, 962408),
#  'item_scraped_count': 10,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 11,
#  'memusage/max': 55193600,
#  'memusage/startup': 55193600,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 14, 39, 8, 396466)}
# 2020-10-24 14:39:08 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Armazenando o resultado em CSV e XML

# %%
# !cd helloscrapy && scrapy crawl spiderone -o items.csv
# Out:
# 2020-10-24 14:39:24 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 14:39:24 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 14:39:24 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 14:39:24 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 14:39:24 [scrapy.extensions.telnet] INFO: Telnet Password: 6dd85a319012d6c6
# 2020-10-24 14:39:24 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 14:39:24 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 14:39:24 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 14:39:24 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-10-24 14:39:24 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 14:39:24 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 14:39:24 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 14:39:24 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://quotes.toscrape.com/robots.txt> (referer: None)
# 2020-10-24 14:39:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/> (referer: None)
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['change', 'deep-thoughts', 'thinking', 'world'],
#  'title': ['“The world as we have created it is a process of our thinking. It '
#            'cannot be changed without changing our thinking.”']}
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['J.K. Rowling'],
#  'tag': ['abilities', 'choices'],
#  'title': ['“It is our choices, Harry, that show what we truly are, far more '
#            'than our abilities.”']}
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['inspirational', 'life', 'live', 'miracle', 'miracles'],
#  'title': ['“There are only two ways to live your life. One is as though '
#            'nothing is a miracle. The other is as though everything is a '
#            'miracle.”']}
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Jane Austen'],
#  'tag': ['aliteracy', 'books', 'classic', 'humor'],
#  'title': ['“The person, be it gentleman or lady, who has not pleasure in a '
#            'good novel, must be intolerably stupid.”']}
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Marilyn Monroe'],
#  'tag': ['be-yourself', 'inspirational'],
#  'title': ["“Imperfection is beauty, madness is genius and it's better to be "
#            'absolutely ridiculous than absolutely boring.”']}
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['adulthood', 'success', 'value'],
#  'title': ['“Try not to become a man of success. Rather become a man of '
#            'value.”']}
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['André Gide'],
#  'tag': ['life', 'love'],
#  'title': ['“It is better to be hated for what you are than to be loved for '
#            'what you are not.”']}
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Thomas A. Edison'],
#  'tag': ['edison', 'failure', 'inspirational', 'paraphrased'],
#  'title': ["“I have not failed. I've just found 10,000 ways that won't work.”"]}
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Eleanor Roosevelt'],
#  'tag': ['misattributed-eleanor-roosevelt'],
#  'title': ['“A woman is like a tea bag; you never know how strong it is until '
#            "it's in hot water.”"]}
# 2020-10-24 14:39:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Steve Martin'],
#  'tag': ['humor', 'obvious', 'simile'],
#  'title': ['“A day without sunshine is like, you know, night.”']}
# 2020-10-24 14:39:24 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 14:39:24 [scrapy.extensions.feedexport] INFO: Stored csv feed (10 items) in: items.csv
# 2020-10-24 14:39:24 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 588,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 2561,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 0.567242,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 14, 39, 24, 727377),
#  'item_scraped_count': 10,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 11,
#  'memusage/max': 55189504,
#  'memusage/startup': 55189504,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 14, 39, 24, 160135)}
# 2020-10-24 14:39:24 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# !cd helloscrapy && scrapy crawl spiderone -o items.xml
# Out:
# 2020-10-24 14:39:26 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 14:39:26 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 14:39:26 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 14:39:26 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 14:39:26 [scrapy.extensions.telnet] INFO: Telnet Password: 64700027f26f002f
# 2020-10-24 14:39:26 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 14:39:26 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 14:39:26 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 14:39:26 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-10-24 14:39:26 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 14:39:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 14:39:26 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 14:39:26 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://quotes.toscrape.com/robots.txt> (referer: None)
# 2020-10-24 14:39:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/> (referer: None)
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['change', 'deep-thoughts', 'thinking', 'world'],
#  'title': ['“The world as we have created it is a process of our thinking. It '
#            'cannot be changed without changing our thinking.”']}
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['J.K. Rowling'],
#  'tag': ['abilities', 'choices'],
#  'title': ['“It is our choices, Harry, that show what we truly are, far more '
#            'than our abilities.”']}
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['inspirational', 'life', 'live', 'miracle', 'miracles'],
#  'title': ['“There are only two ways to live your life. One is as though '
#            'nothing is a miracle. The other is as though everything is a '
#            'miracle.”']}
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Jane Austen'],
#  'tag': ['aliteracy', 'books', 'classic', 'humor'],
#  'title': ['“The person, be it gentleman or lady, who has not pleasure in a '
#            'good novel, must be intolerably stupid.”']}
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Marilyn Monroe'],
#  'tag': ['be-yourself', 'inspirational'],
#  'title': ["“Imperfection is beauty, madness is genius and it's better to be "
#            'absolutely ridiculous than absolutely boring.”']}
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Albert Einstein'],
#  'tag': ['adulthood', 'success', 'value'],
#  'title': ['“Try not to become a man of success. Rather become a man of '
#            'value.”']}
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['André Gide'],
#  'tag': ['life', 'love'],
#  'title': ['“It is better to be hated for what you are than to be loved for '
#            'what you are not.”']}
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Thomas A. Edison'],
#  'tag': ['edison', 'failure', 'inspirational', 'paraphrased'],
#  'title': ["“I have not failed. I've just found 10,000 ways that won't work.”"]}
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Eleanor Roosevelt'],
#  'tag': ['misattributed-eleanor-roosevelt'],
#  'title': ['“A woman is like a tea bag; you never know how strong it is until '
#            "it's in hot water.”"]}
# 2020-10-24 14:39:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'author': ['Steve Martin'],
#  'tag': ['humor', 'obvious', 'simile'],
#  'title': ['“A day without sunshine is like, you know, night.”']}
# 2020-10-24 14:39:26 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 14:39:26 [scrapy.extensions.feedexport] INFO: Stored xml feed (10 items) in: items.xml
# 2020-10-24 14:39:26 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 588,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 2561,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 0.550092,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 14, 39, 26, 651585),
#  'item_scraped_count': 10,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 11,
#  'memusage/max': 55185408,
#  'memusage/startup': 55185408,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 14, 39, 26, 101493)}
# 2020-10-24 14:39:26 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Exercício 3: Coletar os nomes dos produtos na primeira página do Mercado Livre Games e salvar em um arquivo JSON

# %%
# !cd helloscrapy && scrapy crawl spiderone -o nomes.json
# Out:
# 2020-10-24 14:44:42 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 14:44:42 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 14:44:42 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 14:44:42 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 14:44:42 [scrapy.extensions.telnet] INFO: Telnet Password: 82e644c7606b2111
# 2020-10-24 14:44:42 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 14:44:42 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 14:44:42 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 14:44:42 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-10-24 14:44:42 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 14:44:42 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 14:44:42 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 14:44:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://games.mercadolivre.com.br/robots.txt> (referer: None)
# 2020-10-24 14:44:43 [scrapy.robotstxt] WARNING: Failure while parsing robots.txt. File either contains garbage or is in an encoding other than UTF-8, treating it as an empty file.
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/twisted/internet/defer.py", line 1418, in _inlineCallbacks
#     result = g.send(result)
# StopIteration: <200 https://games.mercadolivre.com.br/robots.txt>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/scrapy/robotstxt.py", line 16, in decode_robotstxt
#     robotstxt_body = robotstxt_body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2876: invalid continuation byte
# 2020-10-24 14:44:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://games.mercadolivre.com.br/games/> (referer: None)
# 2020-10-24 14:44:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nomes': ['Fone de ouvido gamer Tedge  preto',
#            'Super Mini Sfc Retrô 620 Jogos 2 Controles Envio Imediato Rj',
#            'Mini Game Retrô Portatil 400 Jogos Antigos Anos 80 Promoção',
#            'Super Mini Game Lcd 3  400 Jogos Portátil Av C/ Controle ',
#            'Mini Video Game Portatil Retrô + 3.000 Jogos Super Nintendo',
#            'Super Nintendo Mini 8 Mil Jogos 2 Controles Envio Imediato!',
#            'The Last Of Us Part 2 Midia Fisica Pronta Entrega Pt-br + Nf',
#            'Cabo Flat Tipo J Play2 Para O Leitor Série 9000x 7000x Slim',
#            'Cockpit Suporte Volante Simulador Logitech G29/920/ps4 Sgt',
#            'Fone De Ouvido Headset Gamer Microfone P2 Tedge',
#            'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles.',
#            'Pes 2020 Ps4 Mídia Fisica Pronta Entrega + Nf',
#            'Pokemon Go Plus Nintendo Com Pulseira Original Lacrado',
#            'Fone Headset Gamer 7.1hd Led Mic  Usb P2 Xbox Ps4 Pc Celular',
#            'Mini Video Game Portatil 400 Jogos Tv Classico - Ax',
#            'Jogo The Last Of Us Part Ii - Ps4 Sony',
#            'Pes 2021 Xbox One Pes 21 Mídia Física Lacrado Pt Br Lacrado',
#            'Mini Game Retrô Portatil 400 Jogos Antigos Anos 80 Promoção',
#            'Playstation 2+ 2 Controle + 1 M.card + Pen Driver 32gb-opl!',
#            'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles.',
#            'Mini Game Portátil Com Controle 400 Jogos Sup Mario Donkey',
#            'Video Game Portátil Vários Jogos Nes Nintendo Sega Gba Mp3',
#            'Headphone Gamer Bass Haiz- 1804 Com Fio Corda Microfone',
#            'Ps4 Grand Theft Auto V 5 Gta 5 Mídia Física Novo Português',
#            'Carregador Controle Ps4 Com Filtro Usb V8 Feir Original',
#            'Pes 2021 Pes 21 Ps4 Mídia Física - Lacrado - Português Novo',
#            'Chave Mini Torx T8 Com Furo Ps3 Ps4 Controle Xbox 360 One',
#            'Playstation 2 + 2 Controle + 1 Memory Card + Jogo+ Garantia!',
#            'Pes 2021 Efootball Pro Evolution Soccer Ps4 Midia Fisica+nf',
#            'Video Game Retro Box Com Jogos Clássicos 64gb Super Barato',
#            'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles',
#            'Fone Gamer Headset Microfone 7.1 Auricular Hd Pc Ps4 Xbox ',
#            'God Of War 4 Ps4 Mídia Física Novo Lacrado',
#            'Karaoke Para Computador E Notebook Completo C/ 9500 Músicas!',
#            'Super Game Box - Video Game Retro Multijogos Clássicos 64gb',
#            'Vídeo Game 7300 Jogos',
#            'Analógico 3d Controle Xbox One Ps4 Direcional 100% Original',
#            'Cabo Flat Tipo J Play2 Para O Leitor Série 9000x 7000x Slim',
#            'Xbox One Grand Theft Auto V 5 Gta V 5  Premium Mídia Física '
#            'Lacrado Legendas Em Português',
#            'Video Game Sfc Mini 620 Jogos Na Memoria 2 Controles 8 Bits.',
#            'Headset 7.1 Gamer Led Ultra Bass Com Vibração Pc Ps4 Mic Usb',
#            'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles',
#            'Playstation 2 + 2 Controle + 1 Memory Card + Brinde 4 Jogos',
#            'Marvels Avengers Vingadores Ps4 - Mídia Física - Lacrado',
#            'Vídeo Game Super Arcade Box 7300 Jogos',
#            'Headset Gamer Redragon Scylla P2 Preto H901',
#            'Vídeo Game Portátil Sup Game Boy 400 Jogos Retro Clássico Nes Gba '
#            'Sega Controle Multiplayer Ligue Tv',
#            'Gran Turismo Sport - Ps4 - Mídia Física - Lacrado',
#            'Xbox 360 Desbloqueado Ltu 3.0 2 Controle Original Hd 500gb ',
#            'Playstation 2 + 2 Controle + 1 Memory Card + Brinde',
#            'Kit Reparo Analógico Joy Con Nintendo Switch']}
# 2020-10-24 14:44:44 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 14:44:44 [scrapy.extensions.feedexport] INFO: Stored json feed (1 items) in: nomes.json
# 2020-10-24 14:44:44 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 660,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 82342,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 1.91822,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 14, 44, 44, 662829),
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'memusage/max': 54747136,
#  'memusage/startup': 54747136,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 14, 44, 42, 744609)}
# 2020-10-24 14:44:44 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Pipelines
# Scraped data > Item Containers > Pipeline > Database

# %% [markdown]
# ## Alterando o arquivo settings.py
# Descomentando a linha ITEM_PIPELINES...

# %% [markdown]
# ## Alterando o arquivo pipeline.py
# Verificando o fluxo de informação passado no pipeline

# %%
# !cd helloscrapy && scrapy crawl spiderone
# Out:
# 2020-10-24 16:39:32 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 16:39:32 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 16:39:32 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 16:39:32 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 16:39:32 [scrapy.extensions.telnet] INFO: Telnet Password: 4730abd5f80f92f8
# 2020-10-24 16:39:32 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 16:39:32 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 16:39:32 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 16:39:32 [scrapy.middleware] INFO: Enabled item pipelines:
# ['helloscrapy.pipelines.HelloscrapyPipeline']
# 2020-10-24 16:39:32 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 16:39:32 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 16:39:32 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 16:39:33 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://quotes.toscrape.com/robots.txt> (referer: None)
# 2020-10-24 16:39:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/> (referer: None)
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'], 'author': ['Albert Einstein'], 'tag': ['change', 'deep-thoughts', 'thinking', 'world']}
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“It is our choices, Harry, that show what we truly are, far more than our abilities.”'], 'author': ['J.K. Rowling'], 'tag': ['abilities', 'choices']}
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”'], 'author': ['Albert Einstein'], 'tag': ['inspirational', 'life', 'live', 'miracle', 'miracles']}
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”'], 'author': ['Jane Austen'], 'tag': ['aliteracy', 'books', 'classic', 'humor']}
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ["“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”"], 'author': ['Marilyn Monroe'], 'tag': ['be-yourself', 'inspirational']}
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“Try not to become a man of success. Rather become a man of value.”'], 'author': ['Albert Einstein'], 'tag': ['adulthood', 'success', 'value']}
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“It is better to be hated for what you are than to be loved for what you are not.”'], 'author': ['André Gide'], 'tag': ['life', 'love']}
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ["“I have not failed. I've just found 10,000 ways that won't work.”"], 'author': ['Thomas A. Edison'], 'tag': ['edison', 'failure', 'inspirational', 'paraphrased']}
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ["“A woman is like a tea bag; you never know how strong it is until it's in hot water.”"], 'author': ['Eleanor Roosevelt'], 'tag': ['misattributed-eleanor-roosevelt']}
# 2020-10-24 16:39:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“A day without sunshine is like, you know, night.”'], 'author': ['Steve Martin'], 'tag': ['humor', 'obvious', 'simile']}
# 2020-10-24 16:39:33 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 16:39:33 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 588,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 2557,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 0.678442,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 16, 39, 33, 661379),
#  'item_scraped_count': 10,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 10,
#  'memusage/max': 55541760,
#  'memusage/startup': 55541760,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 16, 39, 32, 982937)}
# 2020-10-24 16:39:33 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Criando o banco de dados relacional - Sqlite

# %%
# !cd helloscrapy/helloscrapy/ && touch create_database.py

# %%
# !cd helloscrapy/helloscrapy/ && python create_database.py

# %% [markdown]
# ### Visualizando o banco criado
# https://sqliteonline.com/

# %% [markdown]
# ## Inserindo os dados no banco através do arquivo pipeline.py
# Alterando o arquivo pipeline.py

# %%
# !cd helloscrapy && scrapy crawl spiderone
# Out:
# 2020-10-24 16:40:15 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 16:40:15 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 16:40:15 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 16:40:15 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 16:40:15 [scrapy.extensions.telnet] INFO: Telnet Password: 8ae22755a81db3d4
# 2020-10-24 16:40:15 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 16:40:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 16:40:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 16:40:15 [scrapy.middleware] INFO: Enabled item pipelines:
# ['helloscrapy.pipelines.HelloscrapyPipeline']
# 2020-10-24 16:40:15 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 16:40:15 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 16:40:15 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 16:40:15 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://quotes.toscrape.com/robots.txt> (referer: None)
# 2020-10-24 16:40:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/> (referer: None)
# 2020-10-24 16:40:15 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'], 'author': ['Albert Einstein'], 'tag': ['change', 'deep-thoughts', 'thinking', 'world']}
# 2020-10-24 16:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“It is our choices, Harry, that show what we truly are, far more than our abilities.”'], 'author': ['J.K. Rowling'], 'tag': ['abilities', 'choices']}
# 2020-10-24 16:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”'], 'author': ['Albert Einstein'], 'tag': ['inspirational', 'life', 'live', 'miracle', 'miracles']}
# 2020-10-24 16:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”'], 'author': ['Jane Austen'], 'tag': ['aliteracy', 'books', 'classic', 'humor']}
# 2020-10-24 16:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ["“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”"], 'author': ['Marilyn Monroe'], 'tag': ['be-yourself', 'inspirational']}
# 2020-10-24 16:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“Try not to become a man of success. Rather become a man of value.”'], 'author': ['Albert Einstein'], 'tag': ['adulthood', 'success', 'value']}
# 2020-10-24 16:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“It is better to be hated for what you are than to be loved for what you are not.”'], 'author': ['André Gide'], 'tag': ['life', 'love']}
# 2020-10-24 16:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ["“I have not failed. I've just found 10,000 ways that won't work.”"], 'author': ['Thomas A. Edison'], 'tag': ['edison', 'failure', 'inspirational', 'paraphrased']}
# 2020-10-24 16:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ["“A woman is like a tea bag; you never know how strong it is until it's in hot water.”"], 'author': ['Eleanor Roosevelt'], 'tag': ['misattributed-eleanor-roosevelt']}
# 2020-10-24 16:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 http://quotes.toscrape.com/>
# {'title': ['“A day without sunshine is like, you know, night.”'], 'author': ['Steve Martin'], 'tag': ['humor', 'obvious', 'simile']}
# 2020-10-24 16:40:16 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 16:40:16 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 588,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 2557,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 1.36223,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 16, 40, 16, 621455),
#  'item_scraped_count': 10,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 10,
#  'memusage/max': 55472128,
#  'memusage/startup': 55472128,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 16, 40, 15, 259225)}
# 2020-10-24 16:40:16 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Exercício 4: Coletar os nomes dos produtos na primeira página do Mercado Livre Games e armazenar no MongoDB

# %%
db.nomes.drop()

# %%
# !cd helloscrapy && scrapy crawl spiderone
# Out:
# 2020-10-24 17:48:07 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: helloscrapy)
# 2020-10-24 17:48:07 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-101-generic-x86_64-with-debian-buster-sid
# 2020-10-24 17:48:07 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-10-24 17:48:07 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'helloscrapy',
#  'NEWSPIDER_MODULE': 'helloscrapy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['helloscrapy.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
# 2020-10-24 17:48:07 [scrapy.extensions.telnet] INFO: Telnet Password: 4fa8c8f1073b4980
# 2020-10-24 17:48:07 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-24 17:48:07 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-24 17:48:07 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-24 17:48:07 [scrapy.middleware] INFO: Enabled item pipelines:
# ['helloscrapy.pipelines.HelloscrapyPipeline']
# 2020-10-24 17:48:07 [scrapy.core.engine] INFO: Spider opened
# 2020-10-24 17:48:07 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-24 17:48:07 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-24 17:48:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://games.mercadolivre.com.br/robots.txt> (referer: None)
# 2020-10-24 17:48:08 [scrapy.robotstxt] WARNING: Failure while parsing robots.txt. File either contains garbage or is in an encoding other than UTF-8, treating it as an empty file.
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/twisted/internet/defer.py", line 1418, in _inlineCallbacks
#     result = g.send(result)
# StopIteration: <200 https://games.mercadolivre.com.br/robots.txt>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/scrapy/robotstxt.py", line 16, in decode_robotstxt
#     robotstxt_body = robotstxt_body.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2876: invalid continuation byte
# 2020-10-24 17:48:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://games.mercadolivre.com.br/games/> (referer: None)
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Fone de ouvido gamer Tedge  preto'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Super Mini Sfc Retrô 620 Jogos 2 Controles Envio Imediato Rj'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Mini Game Retrô Portatil 400 Jogos Antigos Anos 80 Promoção'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Super Mini Game Lcd 3  400 Jogos Portátil Av C/ Controle '}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Mini Video Game Portatil Retrô + 3.000 Jogos Super Nintendo'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Super Nintendo Mini 8 Mil Jogos 2 Controles Envio Imediato!'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'The Last Of Us Part 2 Midia Fisica Pronta Entrega Pt-br + Nf'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Cabo Flat Tipo J Play2 Para O Leitor Série 9000x 7000x Slim'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Cockpit Suporte Volante Simulador Logitech G29/920/ps4 Sgt'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Fone De Ouvido Headset Gamer Microfone P2 Tedge'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles.'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Pes 2020 Ps4 Mídia Fisica Pronta Entrega + Nf'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Pokemon Go Plus Nintendo Com Pulseira Original Lacrado'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Fone Headset Gamer 7.1hd Led Mic  Usb P2 Xbox Ps4 Pc Celular'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Mini Video Game Portatil 400 Jogos Tv Classico - Ax'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Jogo The Last Of Us Part Ii - Ps4 Sony'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Pes 2021 Xbox One Pes 21 Mídia Física Lacrado Pt Br Lacrado'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Mini Game Retrô Portatil 400 Jogos Antigos Anos 80 Promoção'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Playstation 2+ 2 Controle + 1 M.card + Pen Driver 32gb-opl!'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles.'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Mini Game Portátil Com Controle 400 Jogos Sup Mario Donkey'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Video Game Portátil Vários Jogos Nes Nintendo Sega Gba Mp3'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Headphone Gamer Bass Haiz- 1804 Com Fio Corda Microfone'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Ps4 Grand Theft Auto V 5 Gta 5 Mídia Física Novo Português'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Carregador Controle Ps4 Com Filtro Usb V8 Feir Original'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Pes 2021 Pes 21 Ps4 Mídia Física - Lacrado - Português Novo'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Chave Mini Torx T8 Com Furo Ps3 Ps4 Controle Xbox 360 One'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Playstation 2 + 2 Controle + 1 Memory Card + Jogo+ Garantia!'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Pes 2021 Efootball Pro Evolution Soccer Ps4 Midia Fisica+nf'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Video Game Retro Box Com Jogos Clássicos 64gb Super Barato'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Fone Gamer Headset Microfone 7.1 Auricular Hd Pc Ps4 Xbox '}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'God Of War 4 Ps4 Mídia Física Novo Lacrado'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Karaoke Para Computador E Notebook Completo C/ 9500 Músicas!'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Super Game Box - Video Game Retro Multijogos Clássicos 64gb'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Vídeo Game 7300 Jogos'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Analógico 3d Controle Xbox One Ps4 Direcional 100% Original'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Cabo Flat Tipo J Play2 Para O Leitor Série 9000x 7000x Slim'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Xbox One Grand Theft Auto V 5 Gta V 5  Premium Mídia Física Lacrado Legendas Em Português'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Video Game Sfc Mini 620 Jogos Na Memoria 2 Controles 8 Bits.'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Playstation 2 + 2 Controle + 1 Memory Card + Brinde 4 Jogos'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Headset 7.1 Gamer Led Ultra Bass Com Vibração Pc Ps4 Mic Usb'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Marvels Avengers Vingadores Ps4 - Mídia Física - Lacrado'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Vídeo Game Super Arcade Box 7300 Jogos'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Headset Gamer Redragon Scylla P2 Preto H901'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Playstation 2 + 2 Controle + 1 Memory Card + Brinde'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Vídeo Game Portátil Sup Game Boy 400 Jogos Retro Clássico Nes Gba Sega Controle Multiplayer Ligue Tv'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Gran Turismo Sport - Ps4 - Mídia Física - Lacrado'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Recalbox Pc 2019 Imagem 500gb 12.500 Mil Jogos - 58 Sistemas'}
# 2020-10-24 17:48:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://games.mercadolivre.com.br/games/>
# {'nome': 'Kit Reparo Analógico Joy Con Nintendo Switch'}
# 2020-10-24 17:48:09 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-24 17:48:09 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 660,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 82740,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 1.873932,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 24, 17, 48, 9, 533198),
#  'item_scraped_count': 51,
#  'log_count/DEBUG': 53,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 58068992,
#  'memusage/startup': 58068992,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 24, 17, 48, 7, 659266)}
# 2020-10-24 17:48:09 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
from pymongo import MongoClient
from pprintpp import pprint

mongoclient = MongoClient('localhost', 27017)
db = mongoclient.dbmongo
result = db.nomes.find()

# usando a função pretty print
for i in result:
    pprint( list(result) )
# Out:
# [
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e04'),
#         'nome': 'Super Mini Sfc Retrô 620 Jogos 2 Controles Envio Imediato Rj',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e05'),
#         'nome': 'Mini Game Retrô Portatil 400 Jogos Antigos Anos 80 Promoção',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e06'),
#         'nome': 'Super Mini Game Lcd 3  400 Jogos Portátil Av C/ Controle ',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e07'),
#         'nome': 'Mini Video Game Portatil Retrô + 3.000 Jogos Super Nintendo',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e08'),
#         'nome': 'Super Nintendo Mini 8 Mil Jogos 2 Controles Envio Imediato!',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e09'),
#         'nome': 'The Last Of Us Part 2 Midia Fisica Pronta Entrega Pt-br + Nf',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e0a'),
#         'nome': 'Cabo Flat Tipo J Play2 Para O Leitor Série 9000x 7000x Slim',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e0b'),
#         'nome': 'Cockpit Suporte Volante Simulador Logitech G29/920/ps4 Sgt',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e0c'),
#         'nome': 'Fone De Ouvido Headset Gamer Microfone P2 Tedge',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e0d'),
#         'nome': 'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles.',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e0e'),
#         'nome': 'Pes 2020 Ps4 Mídia Fisica Pronta Entrega + Nf',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e0f'),
#         'nome': 'Pokemon Go Plus Nintendo Com Pulseira Original Lacrado',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e10'),
#         'nome': 'Fone Headset Gamer 7.1hd Led Mic  Usb P2 Xbox Ps4 Pc Celular',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e11'),
#         'nome': 'Mini Video Game Portatil 400 Jogos Tv Classico - Ax',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e12'),
#         'nome': 'Jogo The Last Of Us Part Ii - Ps4 Sony',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e13'),
#         'nome': 'Pes 2021 Xbox One Pes 21 Mídia Física Lacrado Pt Br Lacrado',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e14'),
#         'nome': 'Mini Game Retrô Portatil 400 Jogos Antigos Anos 80 Promoção',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e15'),
#         'nome': 'Playstation 2+ 2 Controle + 1 M.card + Pen Driver 32gb-opl!',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e16'),
#         'nome': 'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles.',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e17'),
#         'nome': 'Mini Game Portátil Com Controle 400 Jogos Sup Mario Donkey',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e18'),
#         'nome': 'Video Game Portátil Vários Jogos Nes Nintendo Sega Gba Mp3',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e19'),
#         'nome': 'Headphone Gamer Bass Haiz- 1804 Com Fio Corda Microfone',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e1a'),
#         'nome': 'Ps4 Grand Theft Auto V 5 Gta 5 Mídia Física Novo Português',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e1b'),
#         'nome': 'Carregador Controle Ps4 Com Filtro Usb V8 Feir Original',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e1c'),
#         'nome': 'Pes 2021 Pes 21 Ps4 Mídia Física - Lacrado - Português Novo',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e1d'),
#         'nome': 'Chave Mini Torx T8 Com Furo Ps3 Ps4 Controle Xbox 360 One',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e1e'),
#         'nome': 'Playstation 2 + 2 Controle + 1 Memory Card + Jogo+ Garantia!',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e1f'),
#         'nome': 'Pes 2021 Efootball Pro Evolution Soccer Ps4 Midia Fisica+nf',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e20'),
#         'nome': 'Video Game Retro Box Com Jogos Clássicos 64gb Super Barato',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e21'),
#         'nome': 'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e22'),
#         'nome': 'Fone Gamer Headset Microfone 7.1 Auricular Hd Pc Ps4 Xbox ',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e23'),
#         'nome': 'God Of War 4 Ps4 Mídia Física Novo Lacrado',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e24'),
#         'nome': 'Karaoke Para Computador E Notebook Completo C/ 9500 Músicas!',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e25'),
#         'nome': 'Super Game Box - Video Game Retro Multijogos Clássicos 64gb',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e26'),
#         'nome': 'Vídeo Game 7300 Jogos',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e27'),
#         'nome': 'Analógico 3d Controle Xbox One Ps4 Direcional 100% Original',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e28'),
#         'nome': 'Cabo Flat Tipo J Play2 Para O Leitor Série 9000x 7000x Slim',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e29'),
#         'nome': 'Xbox One Grand Theft Auto V 5 Gta V 5  Premium Mídia Física Lacrado Legendas Em Português',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e2a'),
#         'nome': 'Video Game Sfc Mini 620 Jogos Na Memoria 2 Controles 8 Bits.',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e2b'),
#         'nome': 'Playstation 2 + 2 Controle + 1 Memory Card + Brinde 4 Jogos',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e2c'),
#         'nome': 'Headset 7.1 Gamer Led Ultra Bass Com Vibração Pc Ps4 Mic Usb',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e2d'),
#         'nome': 'Video Game Super Mini, 620 Jogos 8 Bits 2 Controles',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e2e'),
#         'nome': 'Marvels Avengers Vingadores Ps4 - Mídia Física - Lacrado',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e2f'),
#         'nome': 'Vídeo Game Super Arcade Box 7300 Jogos',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e30'),
#         'nome': 'Headset Gamer Redragon Scylla P2 Preto H901',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e31'),
#         'nome': 'Playstation 2 + 2 Controle + 1 Memory Card + Brinde',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e32'),
#         'nome': 'Vídeo Game Portátil Sup Game Boy 400 Jogos Retro Clássico Nes Gba Sega Controle Multiplayer Ligue Tv',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e33'),
#         'nome': 'Gran Turismo Sport - Ps4 - Mídia Física - Lacrado',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e34'),
#         'nome': 'Recalbox Pc 2019 Imagem 500gb 12.500 Mil Jogos - 58 Sistemas',
#     },
#     {
#         '_id': ObjectId('5f9468d9e5ea858841b11e35'),
#         'nome': 'Kit Reparo Analógico Joy Con Nintendo Switch',
#     },
# ]

# %% [markdown]
# # Armazenando em banco de dados de documentos - MongoDB
# Alterando o arquivo pipeline.py

# %%
# !cd helloscrapy && scrapy crawl spiderone

# %% [markdown]
# ### Consultando diretamente a coleção scrapy_col

# %%
from pymongo import MongoClient
from pprintpp import pprint
import warnings
warnings.filterwarnings('ignore')

mongoclient = MongoClient('localhost', 27017)
db = mongoclient.thedatasocietydb
result = db.scrapy_col.find({})

for document in result:
        pprint(document)
        print()

# %% [markdown]
# # Seguindo links
# Alterando first_spider.py

# %%
# !cd helloscrapy && scrapy crawl spiderone

# %% [markdown]
# # Exercício 5: Coletar o nome, preço e número de avaliações de todos os produtos do Mercado Livre Games e armazenar no MongoDB
